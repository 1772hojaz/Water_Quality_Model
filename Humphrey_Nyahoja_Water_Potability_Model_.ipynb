# %% [markdown]
# # Creating my own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %% [markdown]
# ## **Importing the necessary modules**

# %%
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## **Loading the dataset and Viewing properties of the dataset**

# %%
water_quality_df = pd.read_csv("water_potability.csv")
water_quality_df.head(10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0
# 8       12.706049        53.928846   3.595017           0
# 9       17.927806        71.976601   4.370562           0

# %% [markdown]
# Getting the **dimensions** or **shape** of my dataset

# %%
water_quality_df.shape
# Out:
# (3276, 10)

# %% [markdown]
# Here we are using the **.info()** to get information concerning each columns i.e. **Dtype (data type)** and the total number of **Non-Null** rows for each column, as we can see not all columns have all rows to be **Non-Null**  it should be a total of **3276** non-null rows.

# %%
water_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# But the **.info()** gives us different info but if we want to know just the sum of nullable rows in each column in a better format, we would use the combination of **.isna()** and **sum()** methods.

# %%
water_quality_df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# ### **Checking the Statistical Properties of our data with NAN**

# %%
water_quality_df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %% [markdown]
# ## **Preprocessing Data**

# %% [markdown]
# **First we would fill in the rows with NaN because we dont want to lose vital information, because if we drop rows with nan we lose variety and volume needed for training this model, so we don't want to do that.**

# %%
# we are uing the `interpolate` method in pandas to fill in nan
water_quality_df.interpolate(method='linear', axis=0, limit_direction='both', inplace=True)

# %%
water_quality_df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  3.716080  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  364.639673    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  360.762904    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
water_quality_df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# **We can see that the difference in describe method when water quality dataframe had NaN values and now without any is siginificantly small so the interpolate method I used with the parameters I chose is preserving the overall distribution and chracteristics of our data**

# %%
water_quality_df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.068998   196.369496  22014.092526     7.122277   333.741509
# std       1.534387    32.879761   8768.570828     1.583085    38.870128
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.117357   176.850538  15666.690297     6.127421   310.174409
# 50%       7.034491   196.967627  20927.833607     7.130299   332.960442
# 75%       7.992100   216.667456  27332.762127     8.114887   357.388145
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.461927     3.966786     0.390110
# std       80.824064        3.308162        15.980497     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.988340     3.439711     0.000000
# 50%      421.884968       14.218338        66.691179     3.955028     0.000000
# 75%      481.792304       16.557652        77.215957     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %% [markdown]
# **Creating a correlation matrix to look for multicollinearity between features, which suggests these features are redundant and may not provide additional information for our machine learning model making our model unstable due to misinterpretation of model's coefficient.**

# %%
correlation_matrix = water_quality_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Water Quality Features")
plt.show()

# %% [markdown]
# **Examining our data if there is Potability Label imbalance cause it appears that we have more labels for zeros than one the code below shows that.**

# %%
zero, one = np.bincount(water_quality_df['Potability'])
total = zero + one
print("Examples:\n  Total: {}\n  zero: {} ({:.2f}% of total)\n  one: {} ({:.2f}% of total)".format(
    total, zero, 100 * zero / total, one, 100 * one / total))
# Out:
# Examples:
#   Total: 3276
#   zero: 1998 (60.99% of total)
#   one: 1278 (39.01% of total)

# %% [markdown]
# **Splitting our dataset into 70% train, 15% validation, 15% test**

# %%
train_df, test_df = train_test_split(water_quality_df, test_size=0.15)
train_df, val_df = train_test_split(train_df, test_size=0.15)

# Extract features and labels
train_labels = np.array(train_df.pop('Potability')).reshape(-1, 1)
val_labels = np.array(val_df.pop('Potability')).reshape(-1, 1)
test_labels = np.array(test_df.pop('Potability')).reshape(-1, 1)

train_features = np.array(train_df)
val_features = np.array(val_df)
test_features = np.array(test_df)

print("Train set size:", train_df.shape)
print("Validation set size:", val_df.shape)
print("Test set size:", test_df.shape)
# Out:
# Train set size: (2366, 9)
# Validation set size: (418, 9)
# Test set size: (492, 9)

# %% [markdown]
# **Normalize the data to ensure all features are in the same range, for this we will be using the sklearn StandardScaler. This will set the mean to 0 and standard deviation to 1**

# %% [markdown]
# **Note: The StandardScaler is only fit using the train_features to be sure the model is not peeking at the validation or test sets.**

# %%
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)

val_features = scaler.transform(val_features)
test_features = scaler.transform(test_features)

train_features = np.clip(train_features, -5, 5)
val_features = np.clip(val_features, -5, 5)
test_features = np.clip(test_features, -5, 5)


print('Training labels shape:', train_labels.shape)
print('Validation labels shape:', val_labels.shape)
print('Test labels shape:', test_labels.shape)

print('Training features shape:', train_features.shape)
print('Validation features shape:', val_features.shape)
print('Test features shape:', test_features.shape)
# Out:
# Training labels shape: (2366, 1)
# Validation labels shape: (418, 1)
# Test labels shape: (492, 1)
# Training features shape: (2366, 9)
# Validation features shape: (418, 9)
# Test features shape: (492, 9)

# %% [markdown]
# ## Define the model and metrics
# **Define a function that creates a deep neural network with a densly connected hidden layers, add dropout layer to reduce overfitting if noticed, and an output sigmoid layer that returns the probability of water being potable**

# %%
# Model
METRICS = [
    keras.metrics.BinaryCrossentropy(name="cross_entropy"),
    keras.metrics.MeanSquaredError(name="brier_score"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.BinaryAccuracy(name="accuracy"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
    keras.metrics.AUC(name="auc"),
]

def dense_block(units, dropout_rate=0.5, l2_reg=1e-4):
    """Creates a fully connected block with L2 regularization, Batch Normalization, and Dropout."""
    return [
        keras.layers.Dense(
            units,
            activation=None,
            kernel_initializer="he_normal",
            kernel_regularizer=keras.regularizers.l2(l2_reg),
        ),
        keras.layers.BatchNormalization(),
        keras.layers.ReLU(),
        keras.layers.Dropout(dropout_rate),
    ]

def create_model(input_shape, metrics=METRICS):

    model = keras.Sequential([
        keras.layers.InputLayer(input_shape=input_shape),

        *dense_block(16, dropout_rate=0.2),
        *dense_block(256, dropout_rate=0.3),
        *dense_block(512, dropout_rate=0.4),
        *dense_block(1024, dropout_rate=0.5),
        *dense_block(2048, dropout_rate=0.5),

        keras.layers.Dense(1, activation="sigmoid")
    ])

    lr_scheduler = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1
    )

    # Early Stopping
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=4, restore_best_weights=True, verbose=1
    )

    # Compile model with AdamW (Weight Decay helps generalization)
    model.compile(
        optimizer=keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4),
        loss=keras.losses.Hinge(),
        metrics=metrics,
    )

    return model, [early_stopping, lr_scheduler]

# %% [markdown]
# ###**Understanding useful metrics**
# **Notice that there are a few metrics defined above that can be computed by the model that will be helpful when evaluating the performance. These can be divided into three groups.**
#
# ###**Metrics for probability predictions**
# **As we train our network with the cross entropy as a loss function, it is fully capable of predicting class probabilities, i.e., it is a probabilistic classifier. Good metrics to assess probabilistic predictions are, in fact, proper scoring rules. Their key property is that predicting the true probability is optimal. We give two well-known examples**
#
# **- cross entropy also known as log loss**
#
# **- Mean squared error also known as the Brier score**
#
# ###**Metrics for deterministic 0/1 predictions**
# **In the end, one often wants to predict a class label, 0 or 1, not potable or potable. This is called a deterministic classifier. To get a label prediction from our probabilistic classifier, one needs to choose a probability threshold. The default is to predict label 1 (potable) if the predicted probability is larger than 50%
#  and all the following metrics implicitly use this default.**
#
# **- False negatives and false positives are samples that were incorrectly classified.**
#
# **- True negatives and true positives are samples that were correctly classified.**
#
# **- Accuracy is the percentage of examples correctly classified.**
#
# **- Precision is the percentage of predicted positives that were correctly classified.**
#
# **- Recall is the percentage of actual positives that were correctly classified.**

# %% [markdown]
# ###**Build the model**
# Now create and train your model using the function that was defined earlier. Notice that the model is fit using a larger than default batch size of 2048, this is important to ensure that each batch has a decent chance of containing a few potable samples. If the batch size was too small, they would likely have no potable class to learn from.

# %%
EPOCHS = 800
BATCH_SIZE = 2048

# %%
input_shape = (train_features.shape[-1],)
model, callbacks = create_model(input_shape)
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 16)                  │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_5 (ReLU)                       │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │           4,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_6 (ReLU)                       │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_7 (ReLU)                       │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1024)                │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_8 (ReLU)                       │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 2048)                │       2,099,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_9 (ReLU)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │           2,049 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,778,081 (10.60 MB)
#  Trainable params: 2,770,369 (10.57 MB)
#  Non-trainable params: 7,712 (30.12 KB)

# %% [markdown]
# **Test run the model:**

# %%
history = model.fit(
    train_features,
    train_labels,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(val_features, val_labels))
# Out:
# Epoch 1/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.5071 - auc: 0.4972 - brier_score: 0.3055 - cross_entropy: 0.8720 - fn: 465.6667 - fp: 648.0000 - loss: 1.8766 - precision: 0.3920 - recall: 0.4747 - tn: 728.3333 - tp: 418.0000 - val_accuracy: 0.4019 - val_auc: 0.5125 - val_brier_score: 0.5658 - val_cross_entropy: 2.8528 - val_fn: 0.0000e+00 - val_fp: 250.0000 - val_loss: 1.9559 - val_precision: 0.4019 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 168.0000
# Epoch 2/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 592ms/step - accuracy: 0.5974 - auc: 0.5286 - brier_score: 0.3121 - cross_entropy: 1.0080 - fn: 715.0000 - fp: 194.6667 - loss: 1.7997 - precision: 0.4767 - recall: 0.1990 - tn: 1173.0000 - tp: 177.3333 - val_accuracy: 0.4019 - val_auc: 0.4844 - val_brier_score: 0.5771 - val_cross_entropy: 3.6502 - val_fn: 0.0000e+00 - val_fp: 250.0000 - val_loss: 1.9527 - val_precision: 0.4019 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 168.0000
# Epoch 3/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 443ms/step - accuracy: 0.6130 - auc: 0.5483 - brier_score: 0.3313 - cross_entropy: 1.2860 - fn: 774.3333 - fp: 100.6667 - loss: 1.7691 - precision: 0.5266 - recall: 0.1267 - tn: 1273.0000 - tp: 112.0000 - val_accuracy: 0.4019 - val_auc: 0.4959 - val_brier_score: 0.5654 - val_cross_entropy: 3.4584 - val_fn: 0.0000e+00 - val_fp: 250.0000 - val_loss: 1.9445 - val_precision: 0.4019 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 168.0000
# Epoch 4/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 388ms/step - accuracy: 0.6023 - auc: 0.5408 - brier_score: 0.3575 - cross_entropy: 1.6234 - fn: 839.0000 - fp: 59.3333 - loss: 1.7605 - precision: 0.4788 - recall: 0.0611 - tn: 1307.0000 - tp: 54.6667 - val_accuracy: 0.4067 - val_auc: 0.5008 - val_brier_score: 0.5507 - val_cross_entropy: 3.3370 - val_fn: 2.0000 - val_fp: 246.0000 - val_loss: 1.9362 - val_precision: 0.4029 - val_recall: 0.9881 - val_tn: 4.0000 - val_tp: 166.0000
# Epoch 5/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 448ms/step - accuracy: 0.6139 - auc: 0.5403 - brier_score: 0.3632 - cross_entropy: 1.8804 - fn: 839.0000 - fp: 33.3333 - loss: 1.7472 - precision: 0.6170 - recall: 0.0601 - tn: 1334.0000 - tp: 53.6667 - val_accuracy: 0.4091 - val_auc: 0.5121 - val_brier_score: 0.5344 - val_cross_entropy: 3.2846 - val_fn: 7.0000 - val_fp: 240.0000 - val_loss: 1.9248 - val_precision: 0.4015 - val_recall: 0.9583 - val_tn: 10.0000 - val_tp: 161.0000
# Epoch 6/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 0.6145 - auc: 0.5483 - brier_score: 0.3670 - cross_entropy: 2.1383 - fn: 842.3333 - fp: 29.0000 - loss: 1.7378 - precision: 0.6145 - recall: 0.0521 - tn: 1342.3334 - tp: 46.3333 - val_accuracy: 0.4115 - val_auc: 0.5205 - val_brier_score: 0.5394 - val_cross_entropy: 3.7097 - val_fn: 7.0000 - val_fp: 239.0000 - val_loss: 1.9195 - val_precision: 0.4025 - val_recall: 0.9583 - val_tn: 11.0000 - val_tp: 161.0000
# Epoch 7/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 432ms/step - accuracy: 0.6159 - auc: 0.5560 - brier_score: 0.3672 - cross_entropy: 2.3034 - fn: 837.0000 - fp: 31.0000 - loss: 1.7304 - precision: 0.6233 - recall: 0.0579 - tn: 1340.3334 - tp: 51.6667 - val_accuracy: 0.4067 - val_auc: 0.5133 - val_brier_score: 0.5538 - val_cross_entropy: 4.5034 - val_fn: 6.0000 - val_fp: 242.0000 - val_loss: 1.9177 - val_precision: 0.4010 - val_recall: 0.9643 - val_tn: 8.0000 - val_tp: 162.0000
# Epoch 8/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 595ms/step - accuracy: 0.6089 - auc: 0.5478 - brier_score: 0.3723 - cross_entropy: 2.4999 - fn: 837.0000 - fp: 47.0000 - loss: 1.7278 - precision: 0.5324 - recall: 0.0600 - tn: 1322.6666 - tp: 53.3333 - val_accuracy: 0.4067 - val_auc: 0.4995 - val_brier_score: 0.5676 - val_cross_entropy: 5.5822 - val_fn: 4.0000 - val_fp: 244.0000 - val_loss: 1.9146 - val_precision: 0.4020 - val_recall: 0.9762 - val_tn: 6.0000 - val_tp: 164.0000
# Epoch 9/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 589ms/step - accuracy: 0.6051 - auc: 0.5284 - brier_score: 0.3768 - cross_entropy: 2.6445 - fn: 828.0000 - fp: 64.3333 - loss: 1.7270 - precision: 0.4971 - recall: 0.0714 - tn: 1304.0000 - tp: 63.6667 - val_accuracy: 0.4067 - val_auc: 0.4954 - val_brier_score: 0.5722 - val_cross_entropy: 6.3579 - val_fn: 4.0000 - val_fp: 244.0000 - val_loss: 1.9087 - val_precision: 0.4020 - val_recall: 0.9762 - val_tn: 6.0000 - val_tp: 164.0000
# Epoch 10/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.6085 - auc: 0.5395 - brier_score: 0.3726 - cross_entropy: 2.7535 - fn: 805.6667 - fp: 78.6667 - loss: 1.7169 - precision: 0.5248 - recall: 0.0974 - tn: 1288.6666 - tp: 87.0000 - val_accuracy: 0.4043 - val_auc: 0.5004 - val_brier_score: 0.5706 - val_cross_entropy: 6.5331 - val_fn: 5.0000 - val_fp: 244.0000 - val_loss: 1.9013 - val_precision: 0.4005 - val_recall: 0.9702 - val_tn: 6.0000 - val_tp: 163.0000
# Epoch 11/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 385ms/step - accuracy: 0.6159 - auc: 0.5574 - brier_score: 0.3624 - cross_entropy: 2.7904 - fn: 792.6667 - fp: 75.3333 - loss: 1.7020 - precision: 0.5609 - recall: 0.1084 - tn: 1295.6666 - tp: 96.3333 - val_accuracy: 0.4067 - val_auc: 0.5029 - val_brier_score: 0.5659 - val_cross_entropy: 6.3325 - val_fn: 6.0000 - val_fp: 242.0000 - val_loss: 1.8929 - val_precision: 0.4010 - val_recall: 0.9643 - val_tn: 8.0000 - val_tp: 162.0000
# Epoch 12/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 386ms/step - accuracy: 0.6148 - auc: 0.5451 - brier_score: 0.3685 - cross_entropy: 2.9230 - fn: 811.0000 - fp: 59.3333 - loss: 1.6976 - precision: 0.5782 - recall: 0.0911 - tn: 1308.3334 - tp: 81.3333 - val_accuracy: 0.4139 - val_auc: 0.5012 - val_brier_score: 0.5625 - val_cross_entropy: 6.1591 - val_fn: 6.0000 - val_fp: 239.0000 - val_loss: 1.8854 - val_precision: 0.4040 - val_recall: 0.9643 - val_tn: 11.0000 - val_tp: 162.0000
# Epoch 13/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 385ms/step - accuracy: 0.6201 - auc: 0.5544 - brier_score: 0.3617 - cross_entropy: 2.9345 - fn: 799.3333 - fp: 59.3333 - loss: 1.6869 - precision: 0.6000 - recall: 0.1002 - tn: 1312.3334 - tp: 89.0000 - val_accuracy: 0.4115 - val_auc: 0.5178 - val_brier_score: 0.5603 - val_cross_entropy: 6.1211 - val_fn: 6.0000 - val_fp: 240.0000 - val_loss: 1.8784 - val_precision: 0.4030 - val_recall: 0.9643 - val_tn: 10.0000 - val_tp: 162.0000
# Epoch 14/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 609ms/step - accuracy: 0.6253 - auc: 0.5497 - brier_score: 0.3595 - cross_entropy: 2.9850 - fn: 778.3333 - fp: 69.0000 - loss: 1.6791 - precision: 0.6071 - recall: 0.1206 - tn: 1306.0000 - tp: 106.6667 - val_accuracy: 0.4115 - val_auc: 0.5089 - val_brier_score: 0.5575 - val_cross_entropy: 6.1965 - val_fn: 7.0000 - val_fp: 239.0000 - val_loss: 1.8703 - val_precision: 0.4025 - val_recall: 0.9583 - val_tn: 11.0000 - val_tp: 161.0000
# Epoch 15/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 395ms/step - accuracy: 0.6094 - auc: 0.5418 - brier_score: 0.3710 - cross_entropy: 3.1097 - fn: 794.6667 - fp: 88.0000 - loss: 1.6834 - precision: 0.5238 - recall: 0.1085 - tn: 1280.6666 - tp: 96.6667 - val_accuracy: 0.4211 - val_auc: 0.4995 - val_brier_score: 0.5502 - val_cross_entropy: 6.0957 - val_fn: 9.0000 - val_fp: 233.0000 - val_loss: 1.8605 - val_precision: 0.4056 - val_recall: 0.9464 - val_tn: 17.0000 - val_tp: 159.0000
# Epoch 16/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - accuracy: 0.6204 - auc: 0.5532 - brier_score: 0.3609 - cross_entropy: 3.0678 - fn: 782.3333 - fp: 76.0000 - loss: 1.6702 - precision: 0.5811 - recall: 0.1187 - tn: 1296.3334 - tp: 105.3333 - val_accuracy: 0.4139 - val_auc: 0.5015 - val_brier_score: 0.5390 - val_cross_entropy: 5.6946 - val_fn: 20.0000 - val_fp: 225.0000 - val_loss: 1.8491 - val_precision: 0.3968 - val_recall: 0.8810 - val_tn: 25.0000 - val_tp: 148.0000
# Epoch 17/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - accuracy: 0.6172 - auc: 0.5501 - brier_score: 0.3652 - cross_entropy: 3.1405 - fn: 777.3333 - fp: 88.0000 - loss: 1.6647 - precision: 0.5641 - recall: 0.1277 - tn: 1281.0000 - tp: 113.6667 - val_accuracy: 0.4234 - val_auc: 0.5008 - val_brier_score: 0.5333 - val_cross_entropy: 5.5340 - val_fn: 21.0000 - val_fp: 220.0000 - val_loss: 1.8384 - val_precision: 0.4005 - val_recall: 0.8750 - val_tn: 30.0000 - val_tp: 147.0000
# Epoch 18/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - accuracy: 0.6237 - auc: 0.5542 - brier_score: 0.3601 - cross_entropy: 3.0770 - fn: 758.3333 - fp: 92.3333 - loss: 1.6552 - precision: 0.5848 - recall: 0.1464 - tn: 1279.3334 - tp: 130.0000 - val_accuracy: 0.4330 - val_auc: 0.5063 - val_brier_score: 0.5309 - val_cross_entropy: 5.4678 - val_fn: 23.0000 - val_fp: 214.0000 - val_loss: 1.8303 - val_precision: 0.4039 - val_recall: 0.8631 - val_tn: 36.0000 - val_tp: 145.0000
# Epoch 19/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - accuracy: 0.6232 - auc: 0.5674 - brier_score: 0.3592 - cross_entropy: 3.1660 - fn: 749.3333 - fp: 102.6667 - loss: 1.6482 - precision: 0.5768 - recall: 0.1574 - tn: 1268.3334 - tp: 139.6667 - val_accuracy: 0.4282 - val_auc: 0.5130 - val_brier_score: 0.5275 - val_cross_entropy: 5.2946 - val_fn: 26.0000 - val_fp: 213.0000 - val_loss: 1.8227 - val_precision: 0.4000 - val_recall: 0.8452 - val_tn: 37.0000 - val_tp: 142.0000
# Epoch 20/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 577ms/step - accuracy: 0.6186 - auc: 0.5688 - brier_score: 0.3615 - cross_entropy: 3.1756 - fn: 754.6667 - fp: 107.6667 - loss: 1.6461 - precision: 0.5541 - recall: 0.1506 - tn: 1264.0000 - tp: 133.6667 - val_accuracy: 0.4402 - val_auc: 0.5062 - val_brier_score: 0.5163 - val_cross_entropy: 4.9087 - val_fn: 29.0000 - val_fp: 205.0000 - val_loss: 1.8105 - val_precision: 0.4041 - val_recall: 0.8274 - val_tn: 45.0000 - val_tp: 139.0000
# Epoch 21/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 524ms/step - accuracy: 0.6122 - auc: 0.5560 - brier_score: 0.3692 - cross_entropy: 3.2626 - fn: 759.3333 - fp: 116.6667 - loss: 1.6442 - precision: 0.5376 - recall: 0.1515 - tn: 1248.3334 - tp: 135.6667 - val_accuracy: 0.4617 - val_auc: 0.4931 - val_brier_score: 0.5025 - val_cross_entropy: 4.5425 - val_fn: 37.0000 - val_fp: 188.0000 - val_loss: 1.7950 - val_precision: 0.4107 - val_recall: 0.7798 - val_tn: 62.0000 - val_tp: 131.0000
# Epoch 22/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 432ms/step - accuracy: 0.6214 - auc: 0.5637 - brier_score: 0.3603 - cross_entropy: 3.1711 - fn: 749.3333 - fp: 106.3333 - loss: 1.6318 - precision: 0.5728 - recall: 0.1596 - tn: 1262.0000 - tp: 142.3333 - val_accuracy: 0.4689 - val_auc: 0.4922 - val_brier_score: 0.4897 - val_cross_entropy: 4.2153 - val_fn: 43.0000 - val_fp: 179.0000 - val_loss: 1.7782 - val_precision: 0.4112 - val_recall: 0.7440 - val_tn: 71.0000 - val_tp: 125.0000
# Epoch 23/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 325ms/step - accuracy: 0.6177 - auc: 0.5555 - brier_score: 0.3657 - cross_entropy: 3.3363 - fn: 745.6667 - fp: 118.6667 - loss: 1.6308 - precision: 0.5495 - recall: 0.1624 - tn: 1251.3334 - tp: 144.3333 - val_accuracy: 0.4785 - val_auc: 0.4969 - val_brier_score: 0.4783 - val_cross_entropy: 3.8203 - val_fn: 53.0000 - val_fp: 165.0000 - val_loss: 1.7614 - val_precision: 0.4107 - val_recall: 0.6845 - val_tn: 85.0000 - val_tp: 115.0000
# Epoch 24/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.6177 - auc: 0.5628 - brier_score: 0.3628 - cross_entropy: 3.2912 - fn: 757.3333 - fp: 106.6667 - loss: 1.6225 - precision: 0.5589 - recall: 0.1514 - tn: 1261.0000 - tp: 135.0000 - val_accuracy: 0.4833 - val_auc: 0.5131 - val_brier_score: 0.4590 - val_cross_entropy: 3.4023 - val_fn: 64.0000 - val_fp: 152.0000 - val_loss: 1.7431 - val_precision: 0.4062 - val_recall: 0.6190 - val_tn: 98.0000 - val_tp: 104.0000
# Epoch 25/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - accuracy: 0.6178 - auc: 0.5570 - brier_score: 0.3636 - cross_entropy: 3.2943 - fn: 763.6667 - fp: 99.6667 - loss: 1.6189 - precision: 0.5603 - recall: 0.1428 - tn: 1269.3334 - tp: 127.3333 - val_accuracy: 0.5048 - val_auc: 0.5230 - val_brier_score: 0.4398 - val_cross_entropy: 3.2122 - val_fn: 74.0000 - val_fp: 133.0000 - val_loss: 1.7209 - val_precision: 0.4141 - val_recall: 0.5595 - val_tn: 117.0000 - val_tp: 94.0000
# Epoch 26/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 452ms/step - accuracy: 0.6196 - auc: 0.5681 - brier_score: 0.3626 - cross_entropy: 3.3275 - fn: 757.0000 - fp: 102.3333 - loss: 1.6079 - precision: 0.5743 - recall: 0.1541 - tn: 1262.6666 - tp: 138.0000 - val_accuracy: 0.5311 - val_auc: 0.5284 - val_brier_score: 0.4293 - val_cross_entropy: 3.1694 - val_fn: 75.0000 - val_fp: 121.0000 - val_loss: 1.7049 - val_precision: 0.4346 - val_recall: 0.5536 - val_tn: 129.0000 - val_tp: 93.0000
# Epoch 27/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 495ms/step - accuracy: 0.6307 - auc: 0.5714 - brier_score: 0.3539 - cross_entropy: 3.3615 - fn: 740.3333 - fp: 94.6667 - loss: 1.5989 - precision: 0.6060 - recall: 0.1644 - tn: 1279.3334 - tp: 145.6667 - val_accuracy: 0.5311 - val_auc: 0.5379 - val_brier_score: 0.4222 - val_cross_entropy: 3.0912 - val_fn: 81.0000 - val_fp: 115.0000 - val_loss: 1.6900 - val_precision: 0.4307 - val_recall: 0.5179 - val_tn: 135.0000 - val_tp: 87.0000
# Epoch 28/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 447ms/step - accuracy: 0.6233 - auc: 0.5738 - brier_score: 0.3573 - cross_entropy: 3.4517 - fn: 754.0000 - fp: 97.0000 - loss: 1.5936 - precision: 0.5870 - recall: 0.1546 - tn: 1271.0000 - tp: 138.0000 - val_accuracy: 0.5239 - val_auc: 0.5358 - val_brier_score: 0.4185 - val_cross_entropy: 3.0284 - val_fn: 90.0000 - val_fp: 109.0000 - val_loss: 1.6792 - val_precision: 0.4171 - val_recall: 0.4643 - val_tn: 141.0000 - val_tp: 78.0000
# Epoch 29/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - accuracy: 0.6266 - auc: 0.5623 - brier_score: 0.3575 - cross_entropy: 3.4583 - fn: 743.3333 - fp: 101.0000 - loss: 1.5910 - precision: 0.5903 - recall: 0.1638 - tn: 1270.3334 - tp: 145.3333 - val_accuracy: 0.5167 - val_auc: 0.5408 - val_brier_score: 0.4150 - val_cross_entropy: 2.9981 - val_fn: 95.0000 - val_fp: 107.0000 - val_loss: 1.6698 - val_precision: 0.4056 - val_recall: 0.4345 - val_tn: 143.0000 - val_tp: 73.0000
# Epoch 30/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 0.6188 - auc: 0.5537 - brier_score: 0.3601 - cross_entropy: 3.4886 - fn: 757.3333 - fp: 103.6667 - loss: 1.5884 - precision: 0.5624 - recall: 0.1498 - tn: 1265.3334 - tp: 133.6667 - val_accuracy: 0.5407 - val_auc: 0.5448 - val_brier_score: 0.4099 - val_cross_entropy: 2.9681 - val_fn: 95.0000 - val_fp: 97.0000 - val_loss: 1.6573 - val_precision: 0.4294 - val_recall: 0.4345 - val_tn: 153.0000 - val_tp: 73.0000
# Epoch 31/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 0.6266 - auc: 0.5611 - brier_score: 0.3581 - cross_entropy: 3.4834 - fn: 756.0000 - fp: 87.6667 - loss: 1.5782 - precision: 0.6073 - recall: 0.1520 - tn: 1280.6666 - tp: 135.6667 - val_accuracy: 0.5574 - val_auc: 0.5484 - val_brier_score: 0.4053 - val_cross_entropy: 2.9691 - val_fn: 95.0000 - val_fp: 90.0000 - val_loss: 1.6444 - val_precision: 0.4479 - val_recall: 0.4345 - val_tn: 160.0000 - val_tp: 73.0000
# Epoch 32/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 377ms/step - accuracy: 0.6201 - auc: 0.5626 - brier_score: 0.3630 - cross_entropy: 3.5175 - fn: 767.6667 - fp: 90.6667 - loss: 1.5795 - precision: 0.5783 - recall: 0.1394 - tn: 1277.3334 - tp: 124.3333 - val_accuracy: 0.5478 - val_auc: 0.5450 - val_brier_score: 0.4048 - val_cross_entropy: 3.0189 - val_fn: 97.0000 - val_fp: 92.0000 - val_loss: 1.6388 - val_precision: 0.4356 - val_recall: 0.4226 - val_tn: 158.0000 - val_tp: 71.0000
# Epoch 33/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 390ms/step - accuracy: 0.6329 - auc: 0.5746 - brier_score: 0.3513 - cross_entropy: 3.4958 - fn: 745.0000 - fp: 84.6667 - loss: 1.5632 - precision: 0.6342 - recall: 0.1645 - tn: 1283.6666 - tp: 146.6667 - val_accuracy: 0.5478 - val_auc: 0.5455 - val_brier_score: 0.4083 - val_cross_entropy: 3.1196 - val_fn: 94.0000 - val_fp: 95.0000 - val_loss: 1.6373 - val_precision: 0.4379 - val_recall: 0.4405 - val_tn: 155.0000 - val_tp: 74.0000
# Epoch 34/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.6282 - auc: 0.5714 - brier_score: 0.3552 - cross_entropy: 3.5357 - fn: 733.6667 - fp: 107.0000 - loss: 1.5634 - precision: 0.5906 - recall: 0.1739 - tn: 1265.0000 - tp: 154.3333 - val_accuracy: 0.5239 - val_auc: 0.5445 - val_brier_score: 0.4186 - val_cross_entropy: 3.2583 - val_fn: 89.0000 - val_fp: 110.0000 - val_loss: 1.6408 - val_precision: 0.4180 - val_recall: 0.4702 - val_tn: 140.0000 - val_tp: 79.0000
# Epoch 35/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 552ms/step - accuracy: 0.6283 - auc: 0.5733 - brier_score: 0.3523 - cross_entropy: 3.5532 - fn: 729.0000 - fp: 110.6667 - loss: 1.5561 - precision: 0.5926 - recall: 0.1811 - tn: 1259.0000 - tp: 161.3333 - val_accuracy: 0.5167 - val_auc: 0.5443 - val_brier_score: 0.4273 - val_cross_entropy: 3.4164 - val_fn: 87.0000 - val_fp: 115.0000 - val_loss: 1.6426 - val_precision: 0.4133 - val_recall: 0.4821 - val_tn: 135.0000 - val_tp: 81.0000
# Epoch 36/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 391ms/step - accuracy: 0.6304 - auc: 0.5800 - brier_score: 0.3504 - cross_entropy: 3.5651 - fn: 716.6667 - fp: 118.6667 - loss: 1.5495 - precision: 0.5900 - recall: 0.1926 - tn: 1253.6666 - tp: 171.0000 - val_accuracy: 0.5144 - val_auc: 0.5457 - val_brier_score: 0.4328 - val_cross_entropy: 3.6333 - val_fn: 83.0000 - val_fp: 120.0000 - val_loss: 1.6438 - val_precision: 0.4146 - val_recall: 0.5060 - val_tn: 130.0000 - val_tp: 85.0000
# Epoch 37/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - accuracy: 0.6319 - auc: 0.5785 - brier_score: 0.3541 - cross_entropy: 3.6008 - fn: 700.3333 - fp: 132.0000 - loss: 1.5475 - precision: 0.5874 - recall: 0.2116 - tn: 1240.0000 - tp: 187.6667 - val_accuracy: 0.5144 - val_auc: 0.5427 - val_brier_score: 0.4340 - val_cross_entropy: 3.7881 - val_fn: 78.0000 - val_fp: 125.0000 - val_loss: 1.6402 - val_precision: 0.4186 - val_recall: 0.5357 - val_tn: 125.0000 - val_tp: 90.0000
# Epoch 38/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - accuracy: 0.6281 - auc: 0.5743 - brier_score: 0.3533 - cross_entropy: 3.7152 - fn: 704.3333 - fp: 136.0000 - loss: 1.5421 - precision: 0.5801 - recall: 0.2103 - tn: 1232.0000 - tp: 187.6667 - val_accuracy: 0.5191 - val_auc: 0.5462 - val_brier_score: 0.4337 - val_cross_entropy: 3.8656 - val_fn: 78.0000 - val_fp: 123.0000 - val_loss: 1.6343 - val_precision: 0.4225 - val_recall: 0.5357 - val_tn: 127.0000 - val_tp: 90.0000
# Epoch 39/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.6304 - auc: 0.5673 - brier_score: 0.3532 - cross_entropy: 3.7652 - fn: 703.6667 - fp: 131.6667 - loss: 1.5387 - precision: 0.5839 - recall: 0.2083 - tn: 1239.6666 - tp: 185.0000 - val_accuracy: 0.5215 - val_auc: 0.5438 - val_brier_score: 0.4340 - val_cross_entropy: 3.9312 - val_fn: 78.0000 - val_fp: 122.0000 - val_loss: 1.6298 - val_precision: 0.4245 - val_recall: 0.5357 - val_tn: 128.0000 - val_tp: 90.0000
# Epoch 40/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.6334 - auc: 0.5803 - brier_score: 0.3497 - cross_entropy: 3.7390 - fn: 691.0000 - fp: 137.6667 - loss: 1.5306 - precision: 0.5881 - recall: 0.2215 - tn: 1234.6666 - tp: 196.6667 - val_accuracy: 0.5311 - val_auc: 0.5461 - val_brier_score: 0.4319 - val_cross_entropy: 3.9998 - val_fn: 77.0000 - val_fp: 119.0000 - val_loss: 1.6238 - val_precision: 0.4333 - val_recall: 0.5417 - val_tn: 131.0000 - val_tp: 91.0000
# Epoch 41/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 543ms/step - accuracy: 0.6403 - auc: 0.5959 - brier_score: 0.3441 - cross_entropy: 3.6676 - fn: 697.0000 - fp: 116.3333 - loss: 1.5191 - precision: 0.6230 - recall: 0.2162 - tn: 1254.6666 - tp: 192.0000 - val_accuracy: 0.5239 - val_auc: 0.5465 - val_brier_score: 0.4312 - val_cross_entropy: 4.1041 - val_fn: 77.0000 - val_fp: 122.0000 - val_loss: 1.6192 - val_precision: 0.4272 - val_recall: 0.5417 - val_tn: 128.0000 - val_tp: 91.0000
# Epoch 42/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 507ms/step - accuracy: 0.6282 - auc: 0.5680 - brier_score: 0.3583 - cross_entropy: 3.9574 - fn: 700.6667 - fp: 139.6667 - loss: 1.5275 - precision: 0.5781 - recall: 0.2141 - tn: 1228.6666 - tp: 191.0000 - val_accuracy: 0.5287 - val_auc: 0.5482 - val_brier_score: 0.4330 - val_cross_entropy: 4.1371 - val_fn: 77.0000 - val_fp: 120.0000 - val_loss: 1.6161 - val_precision: 0.4313 - val_recall: 0.5417 - val_tn: 130.0000 - val_tp: 91.0000
# Epoch 43/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.6451 - auc: 0.5912 - brier_score: 0.3404 - cross_entropy: 3.7249 - fn: 671.0000 - fp: 131.0000 - loss: 1.5081 - precision: 0.6273 - recall: 0.2473 - tn: 1237.6666 - tp: 220.3333 - val_accuracy: 0.5191 - val_auc: 0.5460 - val_brier_score: 0.4353 - val_cross_entropy: 4.1752 - val_fn: 80.0000 - val_fp: 121.0000 - val_loss: 1.6151 - val_precision: 0.4211 - val_recall: 0.5238 - val_tn: 129.0000 - val_tp: 88.0000
# Epoch 44/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - accuracy: 0.6354 - auc: 0.5779 - brier_score: 0.3513 - cross_entropy: 3.7870 - fn: 693.0000 - fp: 131.6667 - loss: 1.5160 - precision: 0.5933 - recall: 0.2170 - tn: 1243.3334 - tp: 192.0000 - val_accuracy: 0.5144 - val_auc: 0.5414 - val_brier_score: 0.4360 - val_cross_entropy: 4.1887 - val_fn: 82.0000 - val_fp: 121.0000 - val_loss: 1.6116 - val_precision: 0.4155 - val_recall: 0.5119 - val_tn: 129.0000 - val_tp: 86.0000
# Epoch 45/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 0.6382 - auc: 0.5831 - brier_score: 0.3479 - cross_entropy: 3.8826 - fn: 691.0000 - fp: 126.6667 - loss: 1.5054 - precision: 0.6129 - recall: 0.2247 - tn: 1242.0000 - tp: 200.3333 - val_accuracy: 0.5263 - val_auc: 0.5408 - val_brier_score: 0.4322 - val_cross_entropy: 4.0820 - val_fn: 83.0000 - val_fp: 115.0000 - val_loss: 1.6020 - val_precision: 0.4250 - val_recall: 0.5060 - val_tn: 135.0000 - val_tp: 85.0000
# Epoch 46/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 0.6288 - auc: 0.5701 - brier_score: 0.3540 - cross_entropy: 3.8502 - fn: 701.6667 - fp: 137.6667 - loss: 1.5113 - precision: 0.5724 - recall: 0.2082 - tn: 1236.3334 - tp: 184.3333 - val_accuracy: 0.5359 - val_auc: 0.5480 - val_brier_score: 0.4285 - val_cross_entropy: 3.8947 - val_fn: 87.0000 - val_fp: 107.0000 - val_loss: 1.5901 - val_precision: 0.4309 - val_recall: 0.4821 - val_tn: 143.0000 - val_tp: 81.0000
# Epoch 47/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - accuracy: 0.6345 - auc: 0.5844 - brier_score: 0.3522 - cross_entropy: 3.8099 - fn: 708.6667 - fp: 117.0000 - loss: 1.5006 - precision: 0.6145 - recall: 0.2080 - tn: 1248.0000 - tp: 186.3333 - val_accuracy: 0.5407 - val_auc: 0.5529 - val_brier_score: 0.4177 - val_cross_entropy: 3.6127 - val_fn: 98.0000 - val_fp: 94.0000 - val_loss: 1.5759 - val_precision: 0.4268 - val_recall: 0.4167 - val_tn: 156.0000 - val_tp: 70.0000
# Epoch 48/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - accuracy: 0.6414 - auc: 0.5728 - brier_score: 0.3467 - cross_entropy: 3.8824 - fn: 688.6667 - fp: 121.6667 - loss: 1.4930 - precision: 0.6250 - recall: 0.2271 - tn: 1247.0000 - tp: 202.6667 - val_accuracy: 0.5646 - val_auc: 0.5571 - val_brier_score: 0.4045 - val_cross_entropy: 3.3974 - val_fn: 102.0000 - val_fp: 80.0000 - val_loss: 1.5589 - val_precision: 0.4521 - val_recall: 0.3929 - val_tn: 170.0000 - val_tp: 66.0000
# Epoch 49/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 326ms/step - accuracy: 0.6393 - auc: 0.5790 - brier_score: 0.3465 - cross_entropy: 3.8727 - fn: 697.6667 - fp: 118.0000 - loss: 1.4908 - precision: 0.6135 - recall: 0.2118 - tn: 1257.0000 - tp: 187.3333 - val_accuracy: 0.5478 - val_auc: 0.5570 - val_brier_score: 0.4081 - val_cross_entropy: 3.3716 - val_fn: 119.0000 - val_fp: 70.0000 - val_loss: 1.5570 - val_precision: 0.4118 - val_recall: 0.2917 - val_tn: 180.0000 - val_tp: 49.0000
# Epoch 50/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - accuracy: 0.6390 - auc: 0.5673 - brier_score: 0.3464 - cross_entropy: 3.8654 - fn: 701.6667 - fp: 114.3333 - loss: 1.4860 - precision: 0.6204 - recall: 0.2104 - tn: 1257.0000 - tp: 187.0000 - val_accuracy: 0.5694 - val_auc: 0.5551 - val_brier_score: 0.4018 - val_cross_entropy: 3.4191 - val_fn: 120.0000 - val_fp: 60.0000 - val_loss: 1.5428 - val_precision: 0.4444 - val_recall: 0.2857 - val_tn: 190.0000 - val_tp: 48.0000
# Epoch 51/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 428ms/step - accuracy: 0.6260 - auc: 0.5716 - brier_score: 0.3578 - cross_entropy: 3.9330 - fn: 720.3333 - fp: 125.0000 - loss: 1.4922 - precision: 0.5760 - recall: 0.1908 - tn: 1245.0000 - tp: 169.6667 - val_accuracy: 0.5694 - val_auc: 0.5539 - val_brier_score: 0.3977 - val_cross_entropy: 3.4230 - val_fn: 119.0000 - val_fp: 61.0000 - val_loss: 1.5334 - val_precision: 0.4455 - val_recall: 0.2917 - val_tn: 189.0000 - val_tp: 49.0000
# Epoch 52/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 0.6365 - auc: 0.5729 - brier_score: 0.3506 - cross_entropy: 3.9295 - fn: 708.6667 - fp: 113.0000 - loss: 1.4842 - precision: 0.6096 - recall: 0.1996 - tn: 1261.3334 - tp: 177.0000 - val_accuracy: 0.5766 - val_auc: 0.5497 - val_brier_score: 0.3971 - val_cross_entropy: 3.4219 - val_fn: 118.0000 - val_fp: 59.0000 - val_loss: 1.5281 - val_precision: 0.4587 - val_recall: 0.2976 - val_tn: 191.0000 - val_tp: 50.0000
# Epoch 53/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 310ms/step - accuracy: 0.6335 - auc: 0.5650 - brier_score: 0.3539 - cross_entropy: 3.9922 - fn: 718.3333 - fp: 109.6667 - loss: 1.4805 - precision: 0.6114 - recall: 0.1936 - tn: 1259.3334 - tp: 172.6667 - val_accuracy: 0.5766 - val_auc: 0.5510 - val_brier_score: 0.3959 - val_cross_entropy: 3.4326 - val_fn: 116.0000 - val_fp: 61.0000 - val_loss: 1.5244 - val_precision: 0.4602 - val_recall: 0.3095 - val_tn: 189.0000 - val_tp: 52.0000
# Epoch 54/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 572ms/step - accuracy: 0.6386 - auc: 0.5713 - brier_score: 0.3498 - cross_entropy: 4.0045 - fn: 704.6667 - fp: 112.0000 - loss: 1.4767 - precision: 0.6179 - recall: 0.2048 - tn: 1261.6666 - tp: 181.6667 - val_accuracy: 0.5766 - val_auc: 0.5539 - val_brier_score: 0.3988 - val_cross_entropy: 3.4119 - val_fn: 116.0000 - val_fp: 61.0000 - val_loss: 1.5242 - val_precision: 0.4602 - val_recall: 0.3095 - val_tn: 189.0000 - val_tp: 52.0000
# Epoch 55/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - accuracy: 0.6330 - auc: 0.5702 - brier_score: 0.3521 - cross_entropy: 4.1246 - fn: 712.3333 - fp: 117.3333 - loss: 1.4720 - precision: 0.6040 - recall: 0.2006 - tn: 1251.6666 - tp: 178.6667 - val_accuracy: 0.5646 - val_auc: 0.5620 - val_brier_score: 0.3974 - val_cross_entropy: 3.4075 - val_fn: 117.0000 - val_fp: 65.0000 - val_loss: 1.5200 - val_precision: 0.4397 - val_recall: 0.3036 - val_tn: 185.0000 - val_tp: 51.0000
# Epoch 56/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.6309 - auc: 0.5749 - brier_score: 0.3544 - cross_entropy: 4.1588 - fn: 719.6667 - fp: 114.3333 - loss: 1.4691 - precision: 0.6001 - recall: 0.1925 - tn: 1254.3334 - tp: 171.6667 - val_accuracy: 0.5789 - val_auc: 0.5696 - val_brier_score: 0.3911 - val_cross_entropy: 3.3789 - val_fn: 107.0000 - val_fp: 69.0000 - val_loss: 1.5135 - val_precision: 0.4692 - val_recall: 0.3631 - val_tn: 181.0000 - val_tp: 61.0000
# Epoch 57/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.6365 - auc: 0.5780 - brier_score: 0.3499 - cross_entropy: 4.0917 - fn: 712.3333 - fp: 109.0000 - loss: 1.4621 - precision: 0.6219 - recall: 0.2011 - tn: 1259.3334 - tp: 179.3333 - val_accuracy: 0.5813 - val_auc: 0.5695 - val_brier_score: 0.3943 - val_cross_entropy: 3.4055 - val_fn: 97.0000 - val_fp: 78.0000 - val_loss: 1.5125 - val_precision: 0.4765 - val_recall: 0.4226 - val_tn: 172.0000 - val_tp: 71.0000
# Epoch 58/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 439ms/step - accuracy: 0.6375 - auc: 0.5783 - brier_score: 0.3472 - cross_entropy: 4.0305 - fn: 701.6667 - fp: 118.3333 - loss: 1.4596 - precision: 0.6043 - recall: 0.2050 - tn: 1259.3334 - tp: 180.6667 - val_accuracy: 0.5718 - val_auc: 0.5639 - val_brier_score: 0.3951 - val_cross_entropy: 3.4638 - val_fn: 98.0000 - val_fp: 81.0000 - val_loss: 1.5106 - val_precision: 0.4636 - val_recall: 0.4167 - val_tn: 169.0000 - val_tp: 70.0000
# Epoch 59/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 382ms/step - accuracy: 0.6316 - auc: 0.5732 - brier_score: 0.3545 - cross_entropy: 4.2557 - fn: 714.3333 - fp: 118.6667 - loss: 1.4586 - precision: 0.5953 - recall: 0.1964 - tn: 1252.6666 - tp: 174.3333 - val_accuracy: 0.5742 - val_auc: 0.5603 - val_brier_score: 0.3964 - val_cross_entropy: 3.5363 - val_fn: 92.0000 - val_fp: 86.0000 - val_loss: 1.5085 - val_precision: 0.4691 - val_recall: 0.4524 - val_tn: 164.0000 - val_tp: 76.0000
# Epoch 60/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.6300 - auc: 0.5753 - brier_score: 0.3558 - cross_entropy: 4.2529 - fn: 720.6667 - fp: 115.3333 - loss: 1.4575 - precision: 0.5962 - recall: 0.1912 - tn: 1253.6666 - tp: 170.3333 - val_accuracy: 0.5718 - val_auc: 0.5621 - val_brier_score: 0.4007 - val_cross_entropy: 3.6314 - val_fn: 90.0000 - val_fp: 89.0000 - val_loss: 1.5086 - val_precision: 0.4671 - val_recall: 0.4643 - val_tn: 161.0000 - val_tp: 78.0000
# Epoch 61/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 596ms/step - accuracy: 0.6374 - auc: 0.5752 - brier_score: 0.3518 - cross_entropy: 4.1864 - fn: 704.3333 - fp: 115.3333 - loss: 1.4507 - precision: 0.6168 - recall: 0.2084 - tn: 1255.0000 - tp: 185.3333 - val_accuracy: 0.5694 - val_auc: 0.5657 - val_brier_score: 0.4023 - val_cross_entropy: 3.7386 - val_fn: 88.0000 - val_fp: 92.0000 - val_loss: 1.5074 - val_precision: 0.4651 - val_recall: 0.4762 - val_tn: 158.0000 - val_tp: 80.0000
# Epoch 62/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 529ms/step - accuracy: 0.6359 - auc: 0.5865 - brier_score: 0.3494 - cross_entropy: 4.1731 - fn: 699.6667 - fp: 123.6667 - loss: 1.4455 - precision: 0.6029 - recall: 0.2116 - tn: 1249.0000 - tp: 187.6667 - val_accuracy: 0.5574 - val_auc: 0.5643 - val_brier_score: 0.4016 - val_cross_entropy: 3.7574 - val_fn: 94.0000 - val_fp: 91.0000 - val_loss: 1.5037 - val_precision: 0.4485 - val_recall: 0.4405 - val_tn: 159.0000 - val_tp: 74.0000
# Epoch 63/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.6382 - auc: 0.5814 - brier_score: 0.3456 - cross_entropy: 4.2048 - fn: 682.0000 - fp: 135.6667 - loss: 1.4395 - precision: 0.6077 - recall: 0.2354 - tn: 1232.3334 - tp: 210.0000 - val_accuracy: 0.5670 - val_auc: 0.5645 - val_brier_score: 0.3984 - val_cross_entropy: 3.7201 - val_fn: 95.0000 - val_fp: 86.0000 - val_loss: 1.4981 - val_precision: 0.4591 - val_recall: 0.4345 - val_tn: 164.0000 - val_tp: 73.0000
# Epoch 64/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.6413 - auc: 0.5895 - brier_score: 0.3462 - cross_entropy: 4.2413 - fn: 686.0000 - fp: 124.3333 - loss: 1.4359 - precision: 0.6235 - recall: 0.2310 - tn: 1243.6666 - tp: 206.0000 - val_accuracy: 0.5718 - val_auc: 0.5619 - val_brier_score: 0.3950 - val_cross_entropy: 3.7091 - val_fn: 99.0000 - val_fp: 80.0000 - val_loss: 1.4909 - val_precision: 0.4631 - val_recall: 0.4107 - val_tn: 170.0000 - val_tp: 69.0000
# Epoch 65/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 377ms/step - accuracy: 0.6405 - auc: 0.5804 - brier_score: 0.3471 - cross_entropy: 4.3701 - fn: 681.3333 - fp: 130.6667 - loss: 1.4332 - precision: 0.6184 - recall: 0.2372 - tn: 1236.0000 - tp: 212.0000 - val_accuracy: 0.5813 - val_auc: 0.5597 - val_brier_score: 0.3948 - val_cross_entropy: 3.7880 - val_fn: 99.0000 - val_fp: 76.0000 - val_loss: 1.4859 - val_precision: 0.4759 - val_recall: 0.4107 - val_tn: 174.0000 - val_tp: 69.0000
# Epoch 66/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 441ms/step - accuracy: 0.6418 - auc: 0.5817 - brier_score: 0.3467 - cross_entropy: 4.2667 - fn: 676.0000 - fp: 133.3333 - loss: 1.4282 - precision: 0.6215 - recall: 0.2440 - tn: 1232.3334 - tp: 218.3333 - val_accuracy: 0.5837 - val_auc: 0.5585 - val_brier_score: 0.3920 - val_cross_entropy: 3.8529 - val_fn: 101.0000 - val_fp: 73.0000 - val_loss: 1.4787 - val_precision: 0.4786 - val_recall: 0.3988 - val_tn: 177.0000 - val_tp: 67.0000
# Epoch 67/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 591ms/step - accuracy: 0.6433 - auc: 0.5784 - brier_score: 0.3473 - cross_entropy: 4.4820 - fn: 665.3333 - fp: 140.6667 - loss: 1.4290 - precision: 0.6144 - recall: 0.2522 - tn: 1229.6666 - tp: 224.3333 - val_accuracy: 0.5861 - val_auc: 0.5588 - val_brier_score: 0.3912 - val_cross_entropy: 3.9324 - val_fn: 108.0000 - val_fp: 65.0000 - val_loss: 1.4733 - val_precision: 0.4800 - val_recall: 0.3571 - val_tn: 185.0000 - val_tp: 60.0000
# Epoch 68/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 501ms/step - accuracy: 0.6362 - auc: 0.5907 - brier_score: 0.3516 - cross_entropy: 4.3993 - fn: 685.6667 - fp: 136.6667 - loss: 1.4303 - precision: 0.5962 - recall: 0.2275 - tn: 1235.6666 - tp: 202.0000 - val_accuracy: 0.5766 - val_auc: 0.5584 - val_brier_score: 0.3951 - val_cross_entropy: 4.0368 - val_fn: 110.0000 - val_fp: 67.0000 - val_loss: 1.4739 - val_precision: 0.4640 - val_recall: 0.3452 - val_tn: 183.0000 - val_tp: 58.0000
# Epoch 69/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - accuracy: 0.6486 - auc: 0.5908 - brier_score: 0.3377 - cross_entropy: 4.2496 - fn: 663.0000 - fp: 131.6667 - loss: 1.4148 - precision: 0.6335 - recall: 0.2554 - tn: 1238.3334 - tp: 227.0000 - val_accuracy: 0.5670 - val_auc: 0.5547 - val_brier_score: 0.4027 - val_cross_entropy: 4.1168 - val_fn: 112.0000 - val_fp: 69.0000 - val_loss: 1.4786 - val_precision: 0.4480 - val_recall: 0.3333 - val_tn: 181.0000 - val_tp: 56.0000
# Epoch 70/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.6374 - auc: 0.5812 - brier_score: 0.3506 - cross_entropy: 4.5903 - fn: 662.3333 - fp: 157.0000 - loss: 1.4217 - precision: 0.5928 - recall: 0.2566 - tn: 1212.0000 - tp: 228.6667 - val_accuracy: 0.5670 - val_auc: 0.5520 - val_brier_score: 0.4058 - val_cross_entropy: 4.1751 - val_fn: 109.0000 - val_fp: 72.0000 - val_loss: 1.4786 - val_precision: 0.4504 - val_recall: 0.3512 - val_tn: 178.0000 - val_tp: 59.0000
# Epoch 71/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step - accuracy: 0.6401 - auc: 0.5749 - brier_score: 0.3484 - cross_entropy: 4.5123 - fn: 670.6667 - fp: 142.6667 - loss: 1.4176 - precision: 0.6050 - recall: 0.2457 - tn: 1228.0000 - tp: 218.6667 - val_accuracy: 0.5646 - val_auc: 0.5473 - val_brier_score: 0.4067 - val_cross_entropy: 4.2514 - val_fn: 108.0000 - val_fp: 74.0000 - val_loss: 1.4779 - val_precision: 0.4478 - val_recall: 0.3571 - val_tn: 176.0000 - val_tp: 60.0000
# Epoch 72/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 404ms/step - accuracy: 0.6377 - auc: 0.5925 - brier_score: 0.3475 - cross_entropy: 4.5208 - fn: 659.3333 - fp: 159.3333 - loss: 1.4123 - precision: 0.5928 - recall: 0.2601 - tn: 1209.3334 - tp: 232.0000 - val_accuracy: 0.5718 - val_auc: 0.5506 - val_brier_score: 0.4045 - val_cross_entropy: 4.2937 - val_fn: 106.0000 - val_fp: 73.0000 - val_loss: 1.4733 - val_precision: 0.4593 - val_recall: 0.3690 - val_tn: 177.0000 - val_tp: 62.0000
# Epoch 73/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 0.6365 - auc: 0.5783 - brier_score: 0.3513 - cross_entropy: 4.5718 - fn: 662.0000 - fp: 159.6667 - loss: 1.4152 - precision: 0.5850 - recall: 0.2539 - tn: 1213.0000 - tp: 225.3333 - val_accuracy: 0.5718 - val_auc: 0.5486 - val_brier_score: 0.4035 - val_cross_entropy: 4.3015 - val_fn: 105.0000 - val_fp: 74.0000 - val_loss: 1.4691 - val_precision: 0.4599 - val_recall: 0.3750 - val_tn: 176.0000 - val_tp: 63.0000
# Epoch 74/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 477ms/step - accuracy: 0.6357 - auc: 0.5799 - brier_score: 0.3498 - cross_entropy: 4.5358 - fn: 672.0000 - fp: 150.6667 - loss: 1.4088 - precision: 0.5954 - recall: 0.2482 - tn: 1215.3334 - tp: 222.0000 - val_accuracy: 0.5718 - val_auc: 0.5488 - val_brier_score: 0.4029 - val_cross_entropy: 4.3138 - val_fn: 105.0000 - val_fp: 74.0000 - val_loss: 1.4642 - val_precision: 0.4599 - val_recall: 0.3750 - val_tn: 176.0000 - val_tp: 63.0000
# Epoch 75/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 386ms/step - accuracy: 0.6435 - auc: 0.5936 - brier_score: 0.3426 - cross_entropy: 4.4442 - fn: 673.3333 - fp: 132.3333 - loss: 1.4005 - precision: 0.6180 - recall: 0.2415 - tn: 1240.0000 - tp: 214.3333 - val_accuracy: 0.5742 - val_auc: 0.5527 - val_brier_score: 0.4000 - val_cross_entropy: 4.3082 - val_fn: 107.0000 - val_fp: 71.0000 - val_loss: 1.4562 - val_precision: 0.4621 - val_recall: 0.3631 - val_tn: 179.0000 - val_tp: 61.0000
# Epoch 76/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 0.6493 - auc: 0.5905 - brier_score: 0.3426 - cross_entropy: 4.5599 - fn: 653.6667 - fp: 139.0000 - loss: 1.3954 - precision: 0.6288 - recall: 0.2646 - tn: 1232.0000 - tp: 235.3333 - val_accuracy: 0.5789 - val_auc: 0.5500 - val_brier_score: 0.3991 - val_cross_entropy: 4.3232 - val_fn: 107.0000 - val_fp: 69.0000 - val_loss: 1.4502 - val_precision: 0.4692 - val_recall: 0.3631 - val_tn: 181.0000 - val_tp: 61.0000
# Epoch 77/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - accuracy: 0.6396 - auc: 0.5919 - brier_score: 0.3480 - cross_entropy: 4.7637 - fn: 674.6667 - fp: 139.6667 - loss: 1.3988 - precision: 0.6075 - recall: 0.2426 - tn: 1229.3334 - tp: 216.3333 - val_accuracy: 0.5861 - val_auc: 0.5561 - val_brier_score: 0.3961 - val_cross_entropy: 4.4030 - val_fn: 107.0000 - val_fp: 66.0000 - val_loss: 1.4435 - val_precision: 0.4803 - val_recall: 0.3631 - val_tn: 184.0000 - val_tp: 61.0000
# Epoch 78/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 431ms/step - accuracy: 0.6367 - auc: 0.5933 - brier_score: 0.3477 - cross_entropy: 4.5562 - fn: 681.0000 - fp: 140.0000 - loss: 1.3940 - precision: 0.6042 - recall: 0.2386 - tn: 1225.6666 - tp: 213.3333 - val_accuracy: 0.5909 - val_auc: 0.5546 - val_brier_score: 0.3928 - val_cross_entropy: 4.5099 - val_fn: 109.0000 - val_fp: 62.0000 - val_loss: 1.4373 - val_precision: 0.4876 - val_recall: 0.3512 - val_tn: 188.0000 - val_tp: 59.0000
# Epoch 79/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 403ms/step - accuracy: 0.6419 - auc: 0.5846 - brier_score: 0.3436 - cross_entropy: 4.5658 - fn: 658.0000 - fp: 151.6667 - loss: 1.3921 - precision: 0.6024 - recall: 0.2589 - tn: 1220.6666 - tp: 229.6667 - val_accuracy: 0.5933 - val_auc: 0.5576 - val_brier_score: 0.3898 - val_cross_entropy: 4.5024 - val_fn: 112.0000 - val_fp: 58.0000 - val_loss: 1.4307 - val_precision: 0.4912 - val_recall: 0.3333 - val_tn: 192.0000 - val_tp: 56.0000
# Epoch 80/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 467ms/step - accuracy: 0.6449 - auc: 0.5940 - brier_score: 0.3408 - cross_entropy: 4.5348 - fn: 675.3333 - fp: 127.3333 - loss: 1.3845 - precision: 0.6290 - recall: 0.2421 - tn: 1241.6666 - tp: 215.6667 - val_accuracy: 0.5981 - val_auc: 0.5615 - val_brier_score: 0.3879 - val_cross_entropy: 4.4259 - val_fn: 112.0000 - val_fp: 56.0000 - val_loss: 1.4257 - val_precision: 0.5000 - val_recall: 0.3333 - val_tn: 194.0000 - val_tp: 56.0000
# Epoch 81/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 530ms/step - accuracy: 0.6438 - auc: 0.5936 - brier_score: 0.3429 - cross_entropy: 4.4692 - fn: 666.0000 - fp: 138.6667 - loss: 1.3824 - precision: 0.6205 - recall: 0.2538 - tn: 1228.6666 - tp: 226.6667 - val_accuracy: 0.5957 - val_auc: 0.5577 - val_brier_score: 0.3857 - val_cross_entropy: 4.2953 - val_fn: 115.0000 - val_fp: 54.0000 - val_loss: 1.4201 - val_precision: 0.4953 - val_recall: 0.3155 - val_tn: 196.0000 - val_tp: 53.0000
# Epoch 82/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.6334 - auc: 0.5804 - brier_score: 0.3508 - cross_entropy: 4.5472 - fn: 679.3333 - fp: 149.3333 - loss: 1.3895 - precision: 0.5837 - recall: 0.2357 - tn: 1222.0000 - tp: 209.3333 - val_accuracy: 0.6005 - val_auc: 0.5556 - val_brier_score: 0.3830 - val_cross_entropy: 4.1590 - val_fn: 114.0000 - val_fp: 53.0000 - val_loss: 1.4143 - val_precision: 0.5047 - val_recall: 0.3214 - val_tn: 197.0000 - val_tp: 54.0000
# Epoch 83/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - accuracy: 0.6415 - auc: 0.5854 - brier_score: 0.3449 - cross_entropy: 4.4681 - fn: 684.3333 - fp: 126.0000 - loss: 1.3802 - precision: 0.6180 - recall: 0.2296 - tn: 1245.6666 - tp: 204.0000 - val_accuracy: 0.5933 - val_auc: 0.5616 - val_brier_score: 0.3823 - val_cross_entropy: 4.0340 - val_fn: 115.0000 - val_fp: 55.0000 - val_loss: 1.4138 - val_precision: 0.4907 - val_recall: 0.3155 - val_tn: 195.0000 - val_tp: 53.0000
# Epoch 84/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.6395 - auc: 0.5892 - brier_score: 0.3487 - cross_entropy: 4.5524 - fn: 688.0000 - fp: 127.0000 - loss: 1.3804 - precision: 0.6146 - recall: 0.2275 - tn: 1242.6666 - tp: 202.3333 - val_accuracy: 0.6029 - val_auc: 0.5619 - val_brier_score: 0.3789 - val_cross_entropy: 3.9282 - val_fn: 113.0000 - val_fp: 53.0000 - val_loss: 1.4082 - val_precision: 0.5093 - val_recall: 0.3274 - val_tn: 197.0000 - val_tp: 55.0000
# Epoch 85/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 311ms/step - accuracy: 0.6447 - auc: 0.5860 - brier_score: 0.3428 - cross_entropy: 4.4881 - fn: 679.0000 - fp: 124.3333 - loss: 1.3736 - precision: 0.6280 - recall: 0.2360 - tn: 1247.0000 - tp: 209.6667 - val_accuracy: 0.6053 - val_auc: 0.5689 - val_brier_score: 0.3764 - val_cross_entropy: 3.8594 - val_fn: 113.0000 - val_fp: 52.0000 - val_loss: 1.4038 - val_precision: 0.5140 - val_recall: 0.3274 - val_tn: 198.0000 - val_tp: 55.0000
# Epoch 86/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - accuracy: 0.6379 - auc: 0.5819 - brier_score: 0.3519 - cross_entropy: 4.6636 - fn: 691.0000 - fp: 126.6667 - loss: 1.3765 - precision: 0.6176 - recall: 0.2284 - tn: 1237.6666 - tp: 204.6667 - val_accuracy: 0.6005 - val_auc: 0.5690 - val_brier_score: 0.3753 - val_cross_entropy: 3.8125 - val_fn: 114.0000 - val_fp: 53.0000 - val_loss: 1.3999 - val_precision: 0.5047 - val_recall: 0.3214 - val_tn: 197.0000 - val_tp: 54.0000
# Epoch 87/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 373ms/step - accuracy: 0.6345 - auc: 0.5735 - brier_score: 0.3522 - cross_entropy: 4.7807 - fn: 701.6667 - fp: 124.3333 - loss: 1.3765 - precision: 0.6031 - recall: 0.2122 - tn: 1245.0000 - tp: 189.0000 - val_accuracy: 0.5981 - val_auc: 0.5620 - val_brier_score: 0.3754 - val_cross_entropy: 3.7686 - val_fn: 117.0000 - val_fp: 51.0000 - val_loss: 1.3976 - val_precision: 0.5000 - val_recall: 0.3036 - val_tn: 199.0000 - val_tp: 51.0000
# Epoch 88/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - accuracy: 0.6394 - auc: 0.5896 - brier_score: 0.3471 - cross_entropy: 4.5416 - fn: 699.6667 - fp: 115.0000 - loss: 1.3694 - precision: 0.6240 - recall: 0.2143 - tn: 1254.3334 - tp: 191.0000 - val_accuracy: 0.6053 - val_auc: 0.5659 - val_brier_score: 0.3732 - val_cross_entropy: 3.7255 - val_fn: 117.0000 - val_fp: 48.0000 - val_loss: 1.3925 - val_precision: 0.5152 - val_recall: 0.3036 - val_tn: 202.0000 - val_tp: 51.0000
# Epoch 89/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 488ms/step - accuracy: 0.6384 - auc: 0.5799 - brier_score: 0.3495 - cross_entropy: 4.5912 - fn: 711.0000 - fp: 106.3333 - loss: 1.3709 - precision: 0.6240 - recall: 0.1991 - tn: 1266.0000 - tp: 176.6667 - val_accuracy: 0.6100 - val_auc: 0.5628 - val_brier_score: 0.3704 - val_cross_entropy: 3.6673 - val_fn: 118.0000 - val_fp: 45.0000 - val_loss: 1.3862 - val_precision: 0.5263 - val_recall: 0.2976 - val_tn: 205.0000 - val_tp: 50.0000
# Epoch 90/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 624ms/step - accuracy: 0.6539 - auc: 0.5880 - brier_score: 0.3382 - cross_entropy: 4.6482 - fn: 686.6667 - fp: 96.3333 - loss: 1.3593 - precision: 0.6692 - recall: 0.2215 - tn: 1282.0000 - tp: 195.0000 - val_accuracy: 0.6077 - val_auc: 0.5605 - val_brier_score: 0.3702 - val_cross_entropy: 3.6177 - val_fn: 119.0000 - val_fp: 45.0000 - val_loss: 1.3825 - val_precision: 0.5213 - val_recall: 0.2917 - val_tn: 205.0000 - val_tp: 49.0000
# Epoch 91/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step - accuracy: 0.6432 - auc: 0.5750 - brier_score: 0.3456 - cross_entropy: 4.6754 - fn: 704.6667 - fp: 101.3333 - loss: 1.3602 - precision: 0.6450 - recall: 0.2075 - tn: 1269.3334 - tp: 184.6667 - val_accuracy: 0.6100 - val_auc: 0.5598 - val_brier_score: 0.3697 - val_cross_entropy: 3.5594 - val_fn: 119.0000 - val_fp: 44.0000 - val_loss: 1.3788 - val_precision: 0.5269 - val_recall: 0.2917 - val_tn: 206.0000 - val_tp: 49.0000
# Epoch 92/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 0.6367 - auc: 0.5785 - brier_score: 0.3517 - cross_entropy: 4.5762 - fn: 717.0000 - fp: 104.0000 - loss: 1.3649 - precision: 0.6230 - recall: 0.1935 - tn: 1267.0000 - tp: 172.0000 - val_accuracy: 0.6124 - val_auc: 0.5687 - val_brier_score: 0.3701 - val_cross_entropy: 3.5256 - val_fn: 118.0000 - val_fp: 44.0000 - val_loss: 1.3754 - val_precision: 0.5319 - val_recall: 0.2976 - val_tn: 206.0000 - val_tp: 50.0000
# Epoch 93/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 450ms/step - accuracy: 0.6522 - auc: 0.5888 - brier_score: 0.3375 - cross_entropy: 4.5307 - fn: 700.3333 - fp: 86.0000 - loss: 1.3490 - precision: 0.6860 - recall: 0.2113 - tn: 1286.0000 - tp: 187.6667 - val_accuracy: 0.6100 - val_auc: 0.5750 - val_brier_score: 0.3700 - val_cross_entropy: 3.5649 - val_fn: 120.0000 - val_fp: 43.0000 - val_loss: 1.3734 - val_precision: 0.5275 - val_recall: 0.2857 - val_tn: 207.0000 - val_tp: 48.0000
# Epoch 94/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - accuracy: 0.6379 - auc: 0.5831 - brier_score: 0.3510 - cross_entropy: 4.6781 - fn: 716.6667 - fp: 101.6667 - loss: 1.3599 - precision: 0.6281 - recall: 0.1935 - tn: 1269.6666 - tp: 172.0000 - val_accuracy: 0.6220 - val_auc: 0.5728 - val_brier_score: 0.3654 - val_cross_entropy: 3.6598 - val_fn: 121.0000 - val_fp: 37.0000 - val_loss: 1.3674 - val_precision: 0.5595 - val_recall: 0.2798 - val_tn: 213.0000 - val_tp: 47.0000
# Epoch 95/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - accuracy: 0.6417 - auc: 0.5832 - brier_score: 0.3467 - cross_entropy: 4.7376 - fn: 706.6667 - fp: 103.0000 - loss: 1.3532 - precision: 0.6382 - recall: 0.2048 - tn: 1268.3334 - tp: 182.0000 - val_accuracy: 0.6220 - val_auc: 0.5740 - val_brier_score: 0.3616 - val_cross_entropy: 3.8173 - val_fn: 120.0000 - val_fp: 38.0000 - val_loss: 1.3620 - val_precision: 0.5581 - val_recall: 0.2857 - val_tn: 212.0000 - val_tp: 48.0000
# Epoch 96/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 0.6376 - auc: 0.5841 - brier_score: 0.3505 - cross_entropy: 4.7501 - fn: 712.6667 - fp: 106.3333 - loss: 1.3535 - precision: 0.6272 - recall: 0.2003 - tn: 1262.3334 - tp: 178.6667 - val_accuracy: 0.6220 - val_auc: 0.5815 - val_brier_score: 0.3645 - val_cross_entropy: 4.0631 - val_fn: 119.0000 - val_fp: 39.0000 - val_loss: 1.3628 - val_precision: 0.5568 - val_recall: 0.2917 - val_tn: 211.0000 - val_tp: 49.0000
# Epoch 97/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - accuracy: 0.6402 - auc: 0.5752 - brier_score: 0.3487 - cross_entropy: 4.7201 - fn: 696.3333 - fp: 116.6667 - loss: 1.3509 - precision: 0.6260 - recall: 0.2190 - tn: 1251.6666 - tp: 195.3333 - val_accuracy: 0.6196 - val_auc: 0.5872 - val_brier_score: 0.3702 - val_cross_entropy: 4.2497 - val_fn: 120.0000 - val_fp: 39.0000 - val_loss: 1.3652 - val_precision: 0.5517 - val_recall: 0.2857 - val_tn: 211.0000 - val_tp: 48.0000
# Epoch 98/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 754ms/step - accuracy: 0.6441 - auc: 0.5840 - brier_score: 0.3430 - cross_entropy: 4.7957 - fn: 691.3333 - fp: 113.0000 - loss: 1.3439 - precision: 0.6398 - recall: 0.2250 - tn: 1255.0000 - tp: 200.6667 - val_accuracy: 0.6148 - val_auc: 0.5805 - val_brier_score: 0.3711 - val_cross_entropy: 4.2921 - val_fn: 120.0000 - val_fp: 41.0000 - val_loss: 1.3636 - val_precision: 0.5393 - val_recall: 0.2857 - val_tn: 209.0000 - val_tp: 48.0000
# Epoch 99/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step - accuracy: 0.6440 - auc: 0.5806 - brier_score: 0.3461 - cross_entropy: 4.9552 - fn: 688.6667 - fp: 116.0000 - loss: 1.3451 - precision: 0.6337 - recall: 0.2256 - tn: 1254.6666 - tp: 200.6667 - val_accuracy: 0.6100 - val_auc: 0.5749 - val_brier_score: 0.3713 - val_cross_entropy: 4.2735 - val_fn: 120.0000 - val_fp: 43.0000 - val_loss: 1.3647 - val_precision: 0.5275 - val_recall: 0.2857 - val_tn: 207.0000 - val_tp: 48.0000
# Epoch 100/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step - accuracy: 0.6405 - auc: 0.5875 - brier_score: 0.3470 - cross_entropy: 4.8292 - fn: 694.3333 - fp: 118.3333 - loss: 1.3442 - precision: 0.6219 - recall: 0.2191 - tn: 1252.6666 - tp: 194.6667 - val_accuracy: 0.6053 - val_auc: 0.5830 - val_brier_score: 0.3759 - val_cross_entropy: 4.2690 - val_fn: 118.0000 - val_fp: 47.0000 - val_loss: 1.3681 - val_precision: 0.5155 - val_recall: 0.2976 - val_tn: 203.0000 - val_tp: 50.0000
# Epoch 101/800
# ...
# Epoch 768/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 0.6782 - auc: 0.6403 - brier_score: 0.3138 - cross_entropy: 5.9703 - fn: 553.3333 - fp: 174.0000 - loss: 1.0022 - precision: 0.6655 - recall: 0.3842 - tn: 1187.6666 - tp: 345.0000 - val_accuracy: 0.6340 - val_auc: 0.5692 - val_brier_score: 0.3556 - val_cross_entropy: 6.9209 - val_fn: 129.0000 - val_fp: 24.0000 - val_loss: 1.0411 - val_precision: 0.6190 - val_recall: 0.2321 - val_tn: 226.0000 - val_tp: 39.0000
# Epoch 769/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 0.6871 - auc: 0.6537 - brier_score: 0.3038 - cross_entropy: 5.6477 - fn: 538.0000 - fp: 169.3333 - loss: 0.9947 - precision: 0.6765 - recall: 0.3969 - tn: 1199.0000 - tp: 353.6667 - val_accuracy: 0.6292 - val_auc: 0.5733 - val_brier_score: 0.3602 - val_cross_entropy: 6.8401 - val_fn: 128.0000 - val_fp: 27.0000 - val_loss: 1.0448 - val_precision: 0.5970 - val_recall: 0.2381 - val_tn: 223.0000 - val_tp: 40.0000
# Epoch 770/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.6872 - auc: 0.6509 - brier_score: 0.3061 - cross_entropy: 5.7935 - fn: 540.3333 - fp: 167.0000 - loss: 0.9982 - precision: 0.6746 - recall: 0.3909 - tn: 1206.3334 - tp: 346.3333 - val_accuracy: 0.6292 - val_auc: 0.5780 - val_brier_score: 0.3634 - val_cross_entropy: 6.8053 - val_fn: 129.0000 - val_fp: 26.0000 - val_loss: 1.0470 - val_precision: 0.6000 - val_recall: 0.2321 - val_tn: 224.0000 - val_tp: 39.0000
# Epoch 771/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - accuracy: 0.6835 - auc: 0.6487 - brier_score: 0.3078 - cross_entropy: 5.7386 - fn: 539.6667 - fp: 175.3333 - loss: 0.9985 - precision: 0.6679 - recall: 0.3949 - tn: 1192.3334 - tp: 352.6667 - val_accuracy: 0.6244 - val_auc: 0.5800 - val_brier_score: 0.3684 - val_cross_entropy: 6.8449 - val_fn: 132.0000 - val_fp: 25.0000 - val_loss: 1.0504 - val_precision: 0.5902 - val_recall: 0.2143 - val_tn: 225.0000 - val_tp: 36.0000
# Epoch 772/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - accuracy: 0.6876 - auc: 0.6509 - brier_score: 0.3043 - cross_entropy: 5.8300 - fn: 539.3333 - fp: 166.6667 - loss: 0.9970 - precision: 0.6762 - recall: 0.3925 - tn: 1205.6666 - tp: 348.3333 - val_accuracy: 0.6244 - val_auc: 0.5683 - val_brier_score: 0.3668 - val_cross_entropy: 6.9276 - val_fn: 132.0000 - val_fp: 25.0000 - val_loss: 1.0481 - val_precision: 0.5902 - val_recall: 0.2143 - val_tn: 225.0000 - val_tp: 36.0000
# Epoch 773/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 503ms/step - accuracy: 0.6948 - auc: 0.6584 - brier_score: 0.2974 - cross_entropy: 5.4849 - fn: 516.6667 - fp: 173.0000 - loss: 0.9902 - precision: 0.6826 - recall: 0.4187 - tn: 1198.0000 - tp: 372.3333 - val_accuracy: 0.6292 - val_auc: 0.5652 - val_brier_score: 0.3630 - val_cross_entropy: 7.0125 - val_fn: 134.0000 - val_fp: 21.0000 - val_loss: 1.0456 - val_precision: 0.6182 - val_recall: 0.2024 - val_tn: 229.0000 - val_tp: 34.0000
# Epoch 774/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 429ms/step - accuracy: 0.6833 - auc: 0.6500 - brier_score: 0.3059 - cross_entropy: 5.6638 - fn: 521.0000 - fp: 194.6667 - loss: 0.9992 - precision: 0.6550 - recall: 0.4151 - tn: 1174.6666 - tp: 369.6667 - val_accuracy: 0.6316 - val_auc: 0.5594 - val_brier_score: 0.3631 - val_cross_entropy: 7.0259 - val_fn: 134.0000 - val_fp: 20.0000 - val_loss: 1.0448 - val_precision: 0.6296 - val_recall: 0.2024 - val_tn: 230.0000 - val_tp: 34.0000
# Epoch 775/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 420ms/step - accuracy: 0.6771 - auc: 0.6410 - brier_score: 0.3145 - cross_entropy: 5.8073 - fn: 526.3333 - fp: 203.6667 - loss: 1.0089 - precision: 0.6380 - recall: 0.4056 - tn: 1170.6666 - tp: 359.3333 - val_accuracy: 0.6268 - val_auc: 0.5618 - val_brier_score: 0.3684 - val_cross_entropy: 6.9417 - val_fn: 135.0000 - val_fp: 21.0000 - val_loss: 1.0490 - val_precision: 0.6111 - val_recall: 0.1964 - val_tn: 229.0000 - val_tp: 33.0000
# Epoch 776/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 408ms/step - accuracy: 0.6840 - auc: 0.6498 - brier_score: 0.3085 - cross_entropy: 5.6078 - fn: 544.6667 - fp: 169.3333 - loss: 0.9984 - precision: 0.6732 - recall: 0.3902 - tn: 1197.3334 - tp: 348.6667 - val_accuracy: 0.6244 - val_auc: 0.5618 - val_brier_score: 0.3680 - val_cross_entropy: 6.8246 - val_fn: 134.0000 - val_fp: 23.0000 - val_loss: 1.0503 - val_precision: 0.5965 - val_recall: 0.2024 - val_tn: 227.0000 - val_tp: 34.0000
# Epoch 777/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.6773 - auc: 0.6411 - brier_score: 0.3130 - cross_entropy: 5.4930 - fn: 553.3333 - fp: 176.0000 - loss: 1.0054 - precision: 0.6564 - recall: 0.3781 - tn: 1194.3334 - tp: 336.3333 - val_accuracy: 0.6244 - val_auc: 0.5675 - val_brier_score: 0.3682 - val_cross_entropy: 6.6746 - val_fn: 131.0000 - val_fp: 26.0000 - val_loss: 1.0508 - val_precision: 0.5873 - val_recall: 0.2202 - val_tn: 224.0000 - val_tp: 37.0000
# Epoch 778/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 368ms/step - accuracy: 0.6898 - auc: 0.6468 - brier_score: 0.3034 - cross_entropy: 5.5913 - fn: 549.0000 - fp: 152.3333 - loss: 0.9947 - precision: 0.6911 - recall: 0.3830 - tn: 1218.0000 - tp: 340.6667 - val_accuracy: 0.6244 - val_auc: 0.5680 - val_brier_score: 0.3701 - val_cross_entropy: 6.6077 - val_fn: 129.0000 - val_fp: 28.0000 - val_loss: 1.0526 - val_precision: 0.5821 - val_recall: 0.2321 - val_tn: 222.0000 - val_tp: 39.0000
# Epoch 779/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.6884 - auc: 0.6467 - brier_score: 0.3038 - cross_entropy: 5.5367 - fn: 558.0000 - fp: 146.0000 - loss: 0.9972 - precision: 0.6916 - recall: 0.3702 - tn: 1227.6666 - tp: 328.3333 - val_accuracy: 0.6148 - val_auc: 0.5702 - val_brier_score: 0.3725 - val_cross_entropy: 6.6028 - val_fn: 129.0000 - val_fp: 32.0000 - val_loss: 1.0547 - val_precision: 0.5493 - val_recall: 0.2321 - val_tn: 218.0000 - val_tp: 39.0000
# Epoch 780/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - accuracy: 0.6828 - auc: 0.6464 - brier_score: 0.3093 - cross_entropy: 5.9191 - fn: 560.3333 - fp: 156.6667 - loss: 0.9996 - precision: 0.6785 - recall: 0.3711 - tn: 1212.6666 - tp: 330.3333 - val_accuracy: 0.6172 - val_auc: 0.5734 - val_brier_score: 0.3730 - val_cross_entropy: 6.5875 - val_fn: 127.0000 - val_fp: 33.0000 - val_loss: 1.0558 - val_precision: 0.5541 - val_recall: 0.2440 - val_tn: 217.0000 - val_tp: 41.0000
# Epoch 781/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 570ms/step - accuracy: 0.6946 - auc: 0.6548 - brier_score: 0.2988 - cross_entropy: 5.8402 - fn: 555.6667 - fp: 134.6667 - loss: 0.9887 - precision: 0.7135 - recall: 0.3764 - tn: 1234.3334 - tp: 335.3333 - val_accuracy: 0.6172 - val_auc: 0.5730 - val_brier_score: 0.3730 - val_cross_entropy: 6.5569 - val_fn: 127.0000 - val_fp: 33.0000 - val_loss: 1.0559 - val_precision: 0.5541 - val_recall: 0.2440 - val_tn: 217.0000 - val_tp: 41.0000
# Epoch 782/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 489ms/step - accuracy: 0.6958 - auc: 0.6598 - brier_score: 0.2977 - cross_entropy: 5.5474 - fn: 562.0000 - fp: 125.6667 - loss: 0.9889 - precision: 0.7219 - recall: 0.3674 - tn: 1246.0000 - tp: 326.3333 - val_accuracy: 0.6220 - val_auc: 0.5731 - val_brier_score: 0.3703 - val_cross_entropy: 6.5583 - val_fn: 126.0000 - val_fp: 32.0000 - val_loss: 1.0528 - val_precision: 0.5676 - val_recall: 0.2500 - val_tn: 218.0000 - val_tp: 42.0000
# Epoch 783/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 0.6910 - auc: 0.6487 - brier_score: 0.3026 - cross_entropy: 5.5793 - fn: 567.0000 - fp: 131.3333 - loss: 0.9924 - precision: 0.7121 - recall: 0.3639 - tn: 1237.3334 - tp: 324.3333 - val_accuracy: 0.6196 - val_auc: 0.5686 - val_brier_score: 0.3718 - val_cross_entropy: 6.6066 - val_fn: 127.0000 - val_fp: 32.0000 - val_loss: 1.0541 - val_precision: 0.5616 - val_recall: 0.2440 - val_tn: 218.0000 - val_tp: 41.0000
# Epoch 784/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 413ms/step - accuracy: 0.6878 - auc: 0.6433 - brier_score: 0.3059 - cross_entropy: 5.7557 - fn: 580.6667 - fp: 124.6667 - loss: 0.9957 - precision: 0.7124 - recall: 0.3474 - tn: 1245.3334 - tp: 309.3333 - val_accuracy: 0.6220 - val_auc: 0.5690 - val_brier_score: 0.3727 - val_cross_entropy: 6.6388 - val_fn: 128.0000 - val_fp: 30.0000 - val_loss: 1.0551 - val_precision: 0.5714 - val_recall: 0.2381 - val_tn: 220.0000 - val_tp: 40.0000
# Epoch 785/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 408ms/step - accuracy: 0.6814 - auc: 0.6346 - brier_score: 0.3115 - cross_entropy: 5.4335 - fn: 593.3333 - fp: 126.6667 - loss: 1.0020 - precision: 0.7007 - recall: 0.3333 - tn: 1243.3334 - tp: 296.6667 - val_accuracy: 0.6220 - val_auc: 0.5639 - val_brier_score: 0.3729 - val_cross_entropy: 6.6445 - val_fn: 128.0000 - val_fp: 30.0000 - val_loss: 1.0558 - val_precision: 0.5714 - val_recall: 0.2381 - val_tn: 220.0000 - val_tp: 40.0000
# Epoch 786/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 0.6862 - auc: 0.6458 - brier_score: 0.3080 - cross_entropy: 5.7210 - fn: 582.6667 - fp: 126.6667 - loss: 0.9979 - precision: 0.7068 - recall: 0.3439 - tn: 1245.3334 - tp: 305.3333 - val_accuracy: 0.6172 - val_auc: 0.5632 - val_brier_score: 0.3746 - val_cross_entropy: 6.6721 - val_fn: 130.0000 - val_fp: 30.0000 - val_loss: 1.0571 - val_precision: 0.5588 - val_recall: 0.2262 - val_tn: 220.0000 - val_tp: 38.0000
# Epoch 787/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 0.6931 - auc: 0.6449 - brier_score: 0.3010 - cross_entropy: 5.5723 - fn: 589.0000 - fp: 104.3333 - loss: 0.9884 - precision: 0.7449 - recall: 0.3409 - tn: 1262.0000 - tp: 304.6667 - val_accuracy: 0.6148 - val_auc: 0.5636 - val_brier_score: 0.3754 - val_cross_entropy: 6.6835 - val_fn: 131.0000 - val_fp: 30.0000 - val_loss: 1.0574 - val_precision: 0.5522 - val_recall: 0.2202 - val_tn: 220.0000 - val_tp: 37.0000
# Epoch 788/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 0.6819 - auc: 0.6350 - brier_score: 0.3128 - cross_entropy: 5.9763 - fn: 591.3333 - fp: 127.0000 - loss: 0.9996 - precision: 0.7046 - recall: 0.3386 - tn: 1238.6666 - tp: 303.0000 - val_accuracy: 0.6148 - val_auc: 0.5627 - val_brier_score: 0.3768 - val_cross_entropy: 6.7021 - val_fn: 131.0000 - val_fp: 30.0000 - val_loss: 1.0581 - val_precision: 0.5522 - val_recall: 0.2202 - val_tn: 220.0000 - val_tp: 37.0000
# Epoch 789/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - accuracy: 0.6907 - auc: 0.6393 - brier_score: 0.3044 - cross_entropy: 5.6217 - fn: 581.6667 - fp: 117.3333 - loss: 0.9939 - precision: 0.7243 - recall: 0.3465 - tn: 1252.6666 - tp: 308.3333 - val_accuracy: 0.6148 - val_auc: 0.5581 - val_brier_score: 0.3776 - val_cross_entropy: 6.7203 - val_fn: 132.0000 - val_fp: 29.0000 - val_loss: 1.0579 - val_precision: 0.5538 - val_recall: 0.2143 - val_tn: 221.0000 - val_tp: 36.0000
# Epoch 790/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 472ms/step - accuracy: 0.6847 - auc: 0.6480 - brier_score: 0.3067 - cross_entropy: 5.5917 - fn: 590.6667 - fp: 122.0000 - loss: 0.9971 - precision: 0.7113 - recall: 0.3370 - tn: 1247.0000 - tp: 300.3333 - val_accuracy: 0.6172 - val_auc: 0.5570 - val_brier_score: 0.3772 - val_cross_entropy: 6.7741 - val_fn: 132.0000 - val_fp: 28.0000 - val_loss: 1.0569 - val_precision: 0.5625 - val_recall: 0.2143 - val_tn: 222.0000 - val_tp: 36.0000
# Epoch 791/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 408ms/step - accuracy: 0.6905 - auc: 0.6429 - brier_score: 0.3035 - cross_entropy: 5.8574 - fn: 582.3333 - fp: 117.0000 - loss: 0.9902 - precision: 0.7276 - recall: 0.3489 - tn: 1248.6666 - tp: 312.0000 - val_accuracy: 0.6172 - val_auc: 0.5611 - val_brier_score: 0.3760 - val_cross_entropy: 6.8368 - val_fn: 131.0000 - val_fp: 29.0000 - val_loss: 1.0559 - val_precision: 0.5606 - val_recall: 0.2202 - val_tn: 221.0000 - val_tp: 37.0000
# Epoch 792/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 419ms/step - accuracy: 0.6877 - auc: 0.6463 - brier_score: 0.3065 - cross_entropy: 5.8426 - fn: 568.3333 - fp: 137.3333 - loss: 0.9947 - precision: 0.7025 - recall: 0.3629 - tn: 1230.3334 - tp: 324.0000 - val_accuracy: 0.6268 - val_auc: 0.5665 - val_brier_score: 0.3718 - val_cross_entropy: 6.8845 - val_fn: 130.0000 - val_fp: 26.0000 - val_loss: 1.0521 - val_precision: 0.5938 - val_recall: 0.2262 - val_tn: 224.0000 - val_tp: 38.0000
# Epoch 793/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.6896 - auc: 0.6409 - brier_score: 0.3051 - cross_entropy: 5.6113 - fn: 583.0000 - fp: 118.6667 - loss: 0.9925 - precision: 0.7232 - recall: 0.3468 - tn: 1249.0000 - tp: 309.3333 - val_accuracy: 0.6292 - val_auc: 0.5679 - val_brier_score: 0.3664 - val_cross_entropy: 6.9146 - val_fn: 129.0000 - val_fp: 26.0000 - val_loss: 1.0465 - val_precision: 0.6000 - val_recall: 0.2321 - val_tn: 224.0000 - val_tp: 39.0000
# Epoch 794/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.6872 - auc: 0.6461 - brier_score: 0.3056 - cross_entropy: 5.9866 - fn: 564.6667 - fp: 142.3333 - loss: 0.9963 - precision: 0.6931 - recall: 0.3628 - tn: 1231.3334 - tp: 321.6667 - val_accuracy: 0.6340 - val_auc: 0.5710 - val_brier_score: 0.3631 - val_cross_entropy: 6.9313 - val_fn: 127.0000 - val_fp: 26.0000 - val_loss: 1.0423 - val_precision: 0.6119 - val_recall: 0.2440 - val_tn: 224.0000 - val_tp: 41.0000
# Epoch 795/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 0.6902 - auc: 0.6489 - brier_score: 0.3043 - cross_entropy: 5.7327 - fn: 554.6667 - fp: 145.6667 - loss: 0.9928 - precision: 0.6960 - recall: 0.3756 - tn: 1226.0000 - tp: 333.6667 - val_accuracy: 0.6340 - val_auc: 0.5722 - val_brier_score: 0.3611 - val_cross_entropy: 6.9262 - val_fn: 126.0000 - val_fp: 27.0000 - val_loss: 1.0403 - val_precision: 0.6087 - val_recall: 0.2500 - val_tn: 223.0000 - val_tp: 42.0000
# Epoch 796/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - accuracy: 0.6899 - auc: 0.6431 - brier_score: 0.3056 - cross_entropy: 5.9581 - fn: 554.6667 - fp: 146.3333 - loss: 0.9927 - precision: 0.6976 - recall: 0.3781 - tn: 1222.0000 - tp: 337.0000 - val_accuracy: 0.6364 - val_auc: 0.5703 - val_brier_score: 0.3599 - val_cross_entropy: 6.9029 - val_fn: 125.0000 - val_fp: 27.0000 - val_loss: 1.0394 - val_precision: 0.6143 - val_recall: 0.2560 - val_tn: 223.0000 - val_tp: 43.0000
# Epoch 797/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.6846 - auc: 0.6423 - brier_score: 0.3096 - cross_entropy: 6.1067 - fn: 561.3333 - fp: 151.6667 - loss: 0.9998 - precision: 0.6831 - recall: 0.3683 - tn: 1220.0000 - tp: 327.0000 - val_accuracy: 0.6364 - val_auc: 0.5773 - val_brier_score: 0.3593 - val_cross_entropy: 6.8853 - val_fn: 124.0000 - val_fp: 28.0000 - val_loss: 1.0391 - val_precision: 0.6111 - val_recall: 0.2619 - val_tn: 222.0000 - val_tp: 44.0000
# Epoch 798/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 422ms/step - accuracy: 0.6891 - auc: 0.6485 - brier_score: 0.3038 - cross_entropy: 6.1093 - fn: 545.3333 - fp: 157.0000 - loss: 0.9906 - precision: 0.6887 - recall: 0.3891 - tn: 1210.3334 - tp: 347.3333 - val_accuracy: 0.6364 - val_auc: 0.5720 - val_brier_score: 0.3593 - val_cross_entropy: 6.9183 - val_fn: 123.0000 - val_fp: 29.0000 - val_loss: 1.0391 - val_precision: 0.6081 - val_recall: 0.2679 - val_tn: 221.0000 - val_tp: 45.0000
# Epoch 799/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step - accuracy: 0.6852 - auc: 0.6435 - brier_score: 0.3091 - cross_entropy: 5.8519 - fn: 562.3333 - fp: 149.6667 - loss: 0.9982 - precision: 0.6842 - recall: 0.3658 - tn: 1224.0000 - tp: 324.0000 - val_accuracy: 0.6340 - val_auc: 0.5754 - val_brier_score: 0.3603 - val_cross_entropy: 6.9747 - val_fn: 125.0000 - val_fp: 28.0000 - val_loss: 1.0402 - val_precision: 0.6056 - val_recall: 0.2560 - val_tn: 222.0000 - val_tp: 43.0000
# Epoch 800/800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.6881 - auc: 0.6512 - brier_score: 0.3028 - cross_entropy: 5.9099 - fn: 546.6667 - fp: 158.6667 - loss: 0.9955 - precision: 0.6788 - recall: 0.3808 - tn: 1218.6666 - tp: 336.0000 - val_accuracy: 0.6316 - val_auc: 0.5729 - val_brier_score: 0.3609 - val_cross_entropy: 7.0174 - val_fn: 127.0000 - val_fp: 27.0000 - val_loss: 1.0405 - val_precision: 0.6029 - val_recall: 0.2440 - val_tn: 223.0000 - val_tp: 41.0000

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
test_loss, *other_metrics = model.evaluate(test_features, test_labels, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 1.0208

# %%
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.axhline(y=test_loss, color='g', linestyle='--', label='Test loss')
plt.title('Training, Validation, and Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ###Evaluate metrics
# I would use a confusion matrix to summarize the actual vs. predicted labels, where the X axis is the predicted label and the Y axis is the actual label:

# %%
test_predictions_baseline = model.predict(test_features, batch_size=BATCH_SIZE)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step

# %%
def plot_cm(labels, predictions, threshold=0.5):
  cm = confusion_matrix(labels, predictions > threshold)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(threshold))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Non-Potable Water Detected (True Negatives): ', cm[0][0])
  print('Non-Potable Water Incorrectly Detected (False Positives): ', cm[0][1])
  print('Potable Water Missed (False Negatives): ', cm[1][0])
  print('Potable Water Detected (True Positives): ', cm[1][1])
  print('Total Potable Water: ', np.sum(cm[1]))

# %%
plot_cm(test_labels, test_predictions_baseline)
# Out:
# Non-Potable Water Detected (True Negatives):  294
# Non-Potable Water Incorrectly Detected (False Positives):  20
# Potable Water Missed (False Negatives):  131
# Potable Water Detected (True Positives):  47
# Total Potable Water:  178

# %%
threshold = 0.5
test_predictions_binary = (test_predictions_baseline > threshold).astype(int)

# %%
f1 = f1_score(test_labels, test_predictions_binary)
precision = precision_score(test_labels, test_predictions_binary)
recall = recall_score(test_labels, test_predictions_binary)

print(f"F1 Score: {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
# Out:
# F1 Score: 0.3837
# Precision: 0.7015
# Recall: 0.2640
