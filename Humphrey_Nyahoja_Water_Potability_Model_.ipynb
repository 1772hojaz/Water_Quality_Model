# %% [markdown]
# # Creating my own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %% [markdown]
# ## **Importing the necessary modules**

# %%
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## **Loading the dataset and Viewing properties of the dataset**

# %%
water_quality_df = pd.read_csv("water_potability.csv")
water_quality_df.head(10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0
# 8       12.706049        53.928846   3.595017           0
# 9       17.927806        71.976601   4.370562           0

# %% [markdown]
# Getting the **dimensions** or **shape** of my dataset

# %%
water_quality_df.shape
# Out:
# (3276, 10)

# %% [markdown]
# Here we are using the **.info()** to get information concerning each columns i.e. **Dtype (data type)** and the total number of **Non-Null** rows for each column, as we can see not all columns have all rows to be **Non-Null**  it should be a total of **3276** non-null rows.

# %%
water_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# But the **.info()** gives us different info but if we want to know just the sum of nullable rows in each column in a better format, we would use the combination of **.isna()** and **sum()** methods.

# %%
water_quality_df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# ### **Checking the Statistical Properties of our data with NAN**

# %%
water_quality_df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %% [markdown]
# ## **Preprocessing Data**

# %% [markdown]
# **First we would fill in the rows with NaN because we dont want to lose vital information, because if we drop rows with nan we lose variety and volume needed for training this model, so we don't want to do that.**

# %%
# we are uing the `interpolate` method in pandas to fill in nan
water_quality_df.interpolate(method='linear', axis=0, limit_direction='both', inplace=True)

# %%
water_quality_df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  3.716080  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  364.639673    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  360.762904    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
water_quality_df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# **We can see that the difference in describe method when water quality dataframe had NaN values and now without any is siginificantly small so the interpolate method I used with the parameters I chose is preserving the overall distribution and chracteristics of our data**

# %%
water_quality_df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.068998   196.369496  22014.092526     7.122277   333.741509
# std       1.534387    32.879761   8768.570828     1.583085    38.870128
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.117357   176.850538  15666.690297     6.127421   310.174409
# 50%       7.034491   196.967627  20927.833607     7.130299   332.960442
# 75%       7.992100   216.667456  27332.762127     8.114887   357.388145
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.461927     3.966786     0.390110
# std       80.824064        3.308162        15.980497     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.988340     3.439711     0.000000
# 50%      421.884968       14.218338        66.691179     3.955028     0.000000
# 75%      481.792304       16.557652        77.215957     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %% [markdown]
# **Creating a correlation matrix to look for multicollinearity between features, which suggests these features are redundant and may not provide additional information for our machine learning model making our model unstable due to misinterpretation of model's coefficient.**

# %%
correlation_matrix = water_quality_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Water Quality Features")
plt.show()

# %% [markdown]
# **Examining our data if there is Potability Label imbalance cause it appears that we have more labels for zeros than one the code below shows that.**

# %%
zero, one = np.bincount(water_quality_df['Potability'])
total = zero + one
print("Examples:\n  Total: {}\n  zero: {} ({:.2f}% of total)\n  one: {} ({:.2f}% of total)".format(
    total, zero, 100 * zero / total, one, 100 * one / total))
# Out:
# Examples:
#   Total: 3276
#   zero: 1998 (60.99% of total)
#   one: 1278 (39.01% of total)

# %% [markdown]
# **Splitting our dataset into 70% train, 15% validation, 15% test**

# %%
train_df, test_df = train_test_split(water_quality_df, test_size=0.15)
train_df, val_df = train_test_split(train_df, test_size=0.15)

# Extract features and labels
train_labels = np.array(train_df.pop('Potability')).reshape(-1, 1)
val_labels = np.array(val_df.pop('Potability')).reshape(-1, 1)
test_labels = np.array(test_df.pop('Potability')).reshape(-1, 1)

train_features = np.array(train_df)
val_features = np.array(val_df)
test_features = np.array(test_df)

print("Train set size:", train_df.shape)
print("Validation set size:", val_df.shape)
print("Test set size:", test_df.shape)
# Out:
# Train set size: (2366, 9)
# Validation set size: (418, 9)
# Test set size: (492, 9)

# %% [markdown]
# **Normalize the data to ensure all features are in the same range, for this we will be using the sklearn StandardScaler. This will set the mean to 0 and standard deviation to 1**

# %% [markdown]
# **Note: The StandardScaler is only fit using the train_features to be sure the model is not peeking at the validation or test sets.**

# %%
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)

val_features = scaler.transform(val_features)
test_features = scaler.transform(test_features)

train_features = np.clip(train_features, -5, 5)
val_features = np.clip(val_features, -5, 5)
test_features = np.clip(test_features, -5, 5)


print('Training labels shape:', train_labels.shape)
print('Validation labels shape:', val_labels.shape)
print('Test labels shape:', test_labels.shape)

print('Training features shape:', train_features.shape)
print('Validation features shape:', val_features.shape)
print('Test features shape:', test_features.shape)
# Out:
# Training labels shape: (2366, 1)
# Validation labels shape: (418, 1)
# Test labels shape: (492, 1)
# Training features shape: (2366, 9)
# Validation features shape: (418, 9)
# Test features shape: (492, 9)

# %% [markdown]
# ## Define the model and metrics
# **Define a function that creates a deep neural network with a densly connected hidden layers, add dropout layer to reduce overfitting if noticed, and an output sigmoid layer that returns the probability of water being potable**

# %%
# Model
METRICS = [
    keras.metrics.BinaryCrossentropy(name="cross_entropy"),
    keras.metrics.MeanSquaredError(name="brier_score"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.BinaryAccuracy(name="accuracy"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
    keras.metrics.AUC(name="auc"),
]

def dense_block(units, dropout_rate=0.5, l2_reg=1e-4):
    """a block with L2 regularization, Batch Normalization, and Dropout."""
    return [
        keras.layers.Dense(
            units,
            activation=None,
            kernel_initializer="he_normal",
            kernel_regularizer=keras.regularizers.l2(l2_reg),
        ),
        keras.layers.BatchNormalization(),
        keras.layers.ReLU(),
        keras.layers.Dropout(dropout_rate),
    ]

def create_model(input_shape, metrics=METRICS):

    model = keras.Sequential([
        keras.layers.InputLayer(input_shape=input_shape),

        *dense_block(16, dropout_rate=0.2),
        *dense_block(256, dropout_rate=0.3),
        *dense_block(512, dropout_rate=0.4),
        *dense_block(1024, dropout_rate=0.5),
        *dense_block(2048, dropout_rate=0.5),

        keras.layers.Dense(1, activation="sigmoid")
    ])

    lr_scheduler = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1
    )

    # Early Stopping
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=4, restore_best_weights=True, verbose=1
    )

    # Compile model with AdamW (Weight Decay helps generalization)
    model.compile(
        optimizer=keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4),
        loss=keras.losses.Hinge(),
        metrics=metrics,
    )

    return model, [early_stopping, lr_scheduler]

# %% [markdown]
# ###**Understanding useful metrics**
# **Notice that there are a few metrics defined above that can be computed by the model that will be helpful when evaluating the performance. These can be divided into three groups.**
#
# ###**Metrics for probability predictions**
# **As we train our network with the cross entropy as a loss function, it is fully capable of predicting class probabilities, i.e., it is a probabilistic classifier. Good metrics to assess probabilistic predictions are, in fact, proper scoring rules. Their key property is that predicting the true probability is optimal. We give two well-known examples**
#
# **- cross entropy also known as log loss**
#
# **- Mean squared error also known as the Brier score**
#
# ###**Metrics for deterministic 0/1 predictions**
# **In the end, one often wants to predict a class label, 0 or 1, not potable or potable. This is called a deterministic classifier. To get a label prediction from our probabilistic classifier, one needs to choose a probability threshold. The default is to predict label 1 (potable) if the predicted probability is larger than 50%
#  and all the following metrics implicitly use this default.**
#
# **- False negatives and false positives are samples that were incorrectly classified.**
#
# **- True negatives and true positives are samples that were correctly classified.**
#
# **- Accuracy is the percentage of examples correctly classified.**
#
# **- Precision is the percentage of predicted positives that were correctly classified.**
#
# **- Recall is the percentage of actual positives that were correctly classified.**

# %% [markdown]
# ###**Build the model**
# Now create and train your model using the function that was defined earlier. Notice that the model is fit using a larger than default batch size of 2048, this is important to ensure that each batch has a decent chance of containing a few potable samples. If the batch size was too small, they would likely have no potable class to learn from.

# %%
EPOCHS = 400
BATCH_SIZE = 2048

# %%
input_shape = (train_features.shape[-1],)
model, callbacks = create_model(input_shape)
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │           4,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1024)                │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_3 (ReLU)                       │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 2048)                │       2,099,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_4 (ReLU)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │           2,049 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,778,081 (10.60 MB)
#  Trainable params: 2,770,369 (10.57 MB)
#  Non-trainable params: 7,712 (30.12 KB)

# %% [markdown]
# **Test run the model:**

# %%
history = model.fit(
    train_features,
    train_labels,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(val_features, val_labels))
# Out:
# Epoch 1/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5166 - auc: 0.5098 - brier_score: 0.2947 - cross_entropy: 0.8360 - fn: 485.0000 - fp: 606.6667 - loss: 1.8709 - precision: 0.3963 - recall: 0.4520 - tn: 770.0000 - tp: 398.3333 - val_accuracy: 0.3780 - val_auc: 0.5302 - val_brier_score: 0.5999 - val_cross_entropy: 3.7027 - val_fn: 0.0000e+00 - val_fp: 260.0000 - val_loss: 2.0044 - val_precision: 0.3780 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 158.0000
# Epoch 2/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 382ms/step - accuracy: 0.5836 - auc: 0.5251 - brier_score: 0.3156 - cross_entropy: 1.0113 - fn: 758.3333 - fp: 182.6667 - loss: 1.8064 - precision: 0.4086 - recall: 0.1428 - tn: 1192.6666 - tp: 126.3333 - val_accuracy: 0.3780 - val_auc: 0.5251 - val_brier_score: 0.6147 - val_cross_entropy: 5.4337 - val_fn: 0.0000e+00 - val_fp: 260.0000 - val_loss: 2.0033 - val_precision: 0.3780 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 158.0000
# Epoch 3/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 463ms/step - accuracy: 0.5993 - auc: 0.5317 - brier_score: 0.3413 - cross_entropy: 1.3427 - fn: 798.3333 - fp: 107.3333 - loss: 1.7777 - precision: 0.4387 - recall: 0.0952 - tn: 1270.3334 - tp: 84.0000 - val_accuracy: 0.3780 - val_auc: 0.5486 - val_brier_score: 0.6117 - val_cross_entropy: 5.1004 - val_fn: 0.0000e+00 - val_fp: 260.0000 - val_loss: 1.9968 - val_precision: 0.3780 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 158.0000
# Epoch 4/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 508ms/step - accuracy: 0.6119 - auc: 0.5414 - brier_score: 0.3569 - cross_entropy: 1.6697 - fn: 816.0000 - fp: 61.0000 - loss: 1.7615 - precision: 0.5342 - recall: 0.0790 - tn: 1313.0000 - tp: 70.0000 - val_accuracy: 0.3780 - val_auc: 0.5715 - val_brier_score: 0.5967 - val_cross_entropy: 4.2375 - val_fn: 0.0000e+00 - val_fp: 260.0000 - val_loss: 1.9855 - val_precision: 0.3780 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 158.0000
# Epoch 5/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 325ms/step - accuracy: 0.6140 - auc: 0.5554 - brier_score: 0.3636 - cross_entropy: 1.9572 - fn: 836.6667 - fp: 35.3333 - loss: 1.7473 - precision: 0.6034 - recall: 0.0604 - tn: 1334.3334 - tp: 53.6667 - val_accuracy: 0.3852 - val_auc: 0.5689 - val_brier_score: 0.5694 - val_cross_entropy: 3.7334 - val_fn: 0.0000e+00 - val_fp: 257.0000 - val_loss: 1.9668 - val_precision: 0.3807 - val_recall: 1.0000 - val_tn: 3.0000 - val_tp: 158.0000
# Epoch 6/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 387ms/step - accuracy: 0.6161 - auc: 0.5464 - brier_score: 0.3633 - cross_entropy: 2.1515 - fn: 839.6667 - fp: 28.0000 - loss: 1.7382 - precision: 0.6209 - recall: 0.0517 - tn: 1346.6666 - tp: 45.6667 - val_accuracy: 0.4091 - val_auc: 0.5763 - val_brier_score: 0.5437 - val_cross_entropy: 3.4744 - val_fn: 1.0000 - val_fp: 246.0000 - val_loss: 1.9459 - val_precision: 0.3896 - val_recall: 0.9937 - val_tn: 14.0000 - val_tp: 157.0000
# Epoch 7/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.6159 - auc: 0.5539 - brier_score: 0.3668 - cross_entropy: 2.3469 - fn: 838.0000 - fp: 30.0000 - loss: 1.7322 - precision: 0.6192 - recall: 0.0549 - tn: 1343.3334 - tp: 48.6667 - val_accuracy: 0.4282 - val_auc: 0.5858 - val_brier_score: 0.5228 - val_cross_entropy: 3.2321 - val_fn: 3.0000 - val_fp: 236.0000 - val_loss: 1.9267 - val_precision: 0.3964 - val_recall: 0.9810 - val_tn: 24.0000 - val_tp: 155.0000
# Epoch 8/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.6155 - auc: 0.5544 - brier_score: 0.3708 - cross_entropy: 2.4968 - fn: 846.6667 - fp: 22.6667 - loss: 1.7273 - precision: 0.6250 - recall: 0.0428 - tn: 1353.0000 - tp: 37.6667 - val_accuracy: 0.4402 - val_auc: 0.5822 - val_brier_score: 0.5144 - val_cross_entropy: 3.1681 - val_fn: 4.0000 - val_fp: 230.0000 - val_loss: 1.9143 - val_precision: 0.4010 - val_recall: 0.9747 - val_tn: 30.0000 - val_tp: 154.0000
# Epoch 9/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step - accuracy: 0.6079 - auc: 0.5371 - brier_score: 0.3774 - cross_entropy: 2.7102 - fn: 855.3333 - fp: 30.6667 - loss: 1.7238 - precision: 0.5136 - recall: 0.0365 - tn: 1341.6666 - tp: 32.3333 - val_accuracy: 0.4354 - val_auc: 0.5849 - val_brier_score: 0.4986 - val_cross_entropy: 2.9210 - val_fn: 14.0000 - val_fp: 222.0000 - val_loss: 1.8977 - val_precision: 0.3934 - val_recall: 0.9114 - val_tn: 38.0000 - val_tp: 144.0000
# Epoch 10/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - accuracy: 0.6175 - auc: 0.5433 - brier_score: 0.3697 - cross_entropy: 2.8126 - fn: 845.0000 - fp: 19.0000 - loss: 1.7090 - precision: 0.6968 - recall: 0.0491 - tn: 1352.3334 - tp: 43.6667 - val_accuracy: 0.4474 - val_auc: 0.5957 - val_brier_score: 0.4896 - val_cross_entropy: 2.7906 - val_fn: 16.0000 - val_fp: 215.0000 - val_loss: 1.8846 - val_precision: 0.3978 - val_recall: 0.8987 - val_tn: 45.0000 - val_tp: 142.0000
# Epoch 11/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.6176 - auc: 0.5488 - brier_score: 0.3707 - cross_entropy: 2.8808 - fn: 841.6667 - fp: 22.6667 - loss: 1.7044 - precision: 0.6425 - recall: 0.0463 - tn: 1354.6666 - tp: 41.0000 - val_accuracy: 0.4378 - val_auc: 0.5867 - val_brier_score: 0.4936 - val_cross_entropy: 2.8812 - val_fn: 18.0000 - val_fp: 217.0000 - val_loss: 1.8802 - val_precision: 0.3922 - val_recall: 0.8861 - val_tn: 43.0000 - val_tp: 140.0000
# Epoch 12/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - accuracy: 0.6201 - auc: 0.5464 - brier_score: 0.3708 - cross_entropy: 2.9468 - fn: 842.0000 - fp: 17.0000 - loss: 1.6974 - precision: 0.7091 - recall: 0.0470 - tn: 1359.6666 - tp: 41.3333 - val_accuracy: 0.4330 - val_auc: 0.5711 - val_brier_score: 0.5113 - val_cross_entropy: 3.2531 - val_fn: 15.0000 - val_fp: 222.0000 - val_loss: 1.8854 - val_precision: 0.3918 - val_recall: 0.9051 - val_tn: 38.0000 - val_tp: 143.0000
# Epoch 13/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 495ms/step - accuracy: 0.6167 - auc: 0.5482 - brier_score: 0.3717 - cross_entropy: 3.0233 - fn: 837.6667 - fp: 28.6667 - loss: 1.6898 - precision: 0.6279 - recall: 0.0546 - tn: 1345.3334 - tp: 48.3333 - val_accuracy: 0.4258 - val_auc: 0.5721 - val_brier_score: 0.5257 - val_cross_entropy: 3.6102 - val_fn: 12.0000 - val_fp: 228.0000 - val_loss: 1.8870 - val_precision: 0.3904 - val_recall: 0.9241 - val_tn: 32.0000 - val_tp: 146.0000
# Epoch 14/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 517ms/step - accuracy: 0.6218 - auc: 0.5664 - brier_score: 0.3661 - cross_entropy: 3.0266 - fn: 827.6667 - fp: 27.0000 - loss: 1.6782 - precision: 0.6776 - recall: 0.0643 - tn: 1348.3334 - tp: 57.0000 - val_accuracy: 0.4163 - val_auc: 0.5590 - val_brier_score: 0.5380 - val_cross_entropy: 4.0840 - val_fn: 12.0000 - val_fp: 232.0000 - val_loss: 1.8866 - val_precision: 0.3862 - val_recall: 0.9241 - val_tn: 28.0000 - val_tp: 146.0000
# Epoch 15/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 299ms/step - accuracy: 0.6165 - auc: 0.5320 - brier_score: 0.3702 - cross_entropy: 3.1267 - fn: 826.3333 - fp: 40.3333 - loss: 1.6756 - precision: 0.5959 - recall: 0.0670 - tn: 1334.0000 - tp: 59.3333 - val_accuracy: 0.4115 - val_auc: 0.5425 - val_brier_score: 0.5460 - val_cross_entropy: 4.4872 - val_fn: 13.0000 - val_fp: 233.0000 - val_loss: 1.8843 - val_precision: 0.3836 - val_recall: 0.9177 - val_tn: 27.0000 - val_tp: 145.0000
# Epoch 16/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 305ms/step - accuracy: 0.6276 - auc: 0.5452 - brier_score: 0.3639 - cross_entropy: 3.1505 - fn: 803.6667 - fp: 38.3333 - loss: 1.6644 - precision: 0.6763 - recall: 0.0908 - tn: 1338.0000 - tp: 80.0000 - val_accuracy: 0.4091 - val_auc: 0.5446 - val_brier_score: 0.5475 - val_cross_entropy: 4.7291 - val_fn: 14.0000 - val_fp: 233.0000 - val_loss: 1.8780 - val_precision: 0.3820 - val_recall: 0.9114 - val_tn: 27.0000 - val_tp: 144.0000
# Epoch 17/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - accuracy: 0.6218 - auc: 0.5553 - brier_score: 0.3652 - cross_entropy: 3.2120 - fn: 811.6667 - fp: 43.3333 - loss: 1.6589 - precision: 0.6303 - recall: 0.0833 - tn: 1331.3334 - tp: 73.6667 - val_accuracy: 0.4019 - val_auc: 0.5492 - val_brier_score: 0.5492 - val_cross_entropy: 5.0625 - val_fn: 14.0000 - val_fp: 236.0000 - val_loss: 1.8715 - val_precision: 0.3789 - val_recall: 0.9114 - val_tn: 24.0000 - val_tp: 144.0000
# Epoch 18/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.6218 - auc: 0.5573 - brier_score: 0.3600 - cross_entropy: 3.1866 - fn: 790.6667 - fp: 64.3333 - loss: 1.6502 - precision: 0.5852 - recall: 0.1032 - tn: 1314.0000 - tp: 91.0000 - val_accuracy: 0.4067 - val_auc: 0.5437 - val_brier_score: 0.5472 - val_cross_entropy: 5.3525 - val_fn: 13.0000 - val_fp: 235.0000 - val_loss: 1.8620 - val_precision: 0.3816 - val_recall: 0.9177 - val_tn: 25.0000 - val_tp: 145.0000
# Epoch 19/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.6313 - auc: 0.5660 - brier_score: 0.3540 - cross_entropy: 3.1916 - fn: 766.0000 - fp: 67.3333 - loss: 1.6345 - precision: 0.6441 - recall: 0.1372 - tn: 1305.0000 - tp: 121.6667 - val_accuracy: 0.4139 - val_auc: 0.5441 - val_brier_score: 0.5390 - val_cross_entropy: 5.3632 - val_fn: 14.0000 - val_fp: 231.0000 - val_loss: 1.8489 - val_precision: 0.3840 - val_recall: 0.9114 - val_tn: 29.0000 - val_tp: 144.0000
# Epoch 20/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.6262 - auc: 0.5617 - brier_score: 0.3581 - cross_entropy: 3.2129 - fn: 774.3333 - fp: 70.0000 - loss: 1.6326 - precision: 0.6201 - recall: 0.1286 - tn: 1301.3334 - tp: 114.3333 - val_accuracy: 0.4258 - val_auc: 0.5468 - val_brier_score: 0.5246 - val_cross_entropy: 5.1025 - val_fn: 17.0000 - val_fp: 223.0000 - val_loss: 1.8312 - val_precision: 0.3874 - val_recall: 0.8924 - val_tn: 37.0000 - val_tp: 141.0000
# Epoch 21/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.6180 - auc: 0.5471 - brier_score: 0.3672 - cross_entropy: 3.3529 - fn: 781.0000 - fp: 82.0000 - loss: 1.6361 - precision: 0.5645 - recall: 0.1197 - tn: 1290.6666 - tp: 106.3333 - val_accuracy: 0.4569 - val_auc: 0.5508 - val_brier_score: 0.5074 - val_cross_entropy: 4.7142 - val_fn: 20.0000 - val_fp: 207.0000 - val_loss: 1.8104 - val_precision: 0.4000 - val_recall: 0.8734 - val_tn: 53.0000 - val_tp: 138.0000
# Epoch 22/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 496ms/step - accuracy: 0.6178 - auc: 0.5649 - brier_score: 0.3657 - cross_entropy: 3.3423 - fn: 771.0000 - fp: 92.3333 - loss: 1.6289 - precision: 0.5602 - recall: 0.1323 - tn: 1279.0000 - tp: 117.6667 - val_accuracy: 0.4713 - val_auc: 0.5642 - val_brier_score: 0.4932 - val_cross_entropy: 4.2323 - val_fn: 25.0000 - val_fp: 196.0000 - val_loss: 1.7928 - val_precision: 0.4043 - val_recall: 0.8418 - val_tn: 64.0000 - val_tp: 133.0000
# Epoch 23/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 511ms/step - accuracy: 0.6234 - auc: 0.5527 - brier_score: 0.3620 - cross_entropy: 3.3306 - fn: 760.3333 - fp: 90.6667 - loss: 1.6194 - precision: 0.5808 - recall: 0.1418 - tn: 1283.3334 - tp: 125.6667 - val_accuracy: 0.4737 - val_auc: 0.5699 - val_brier_score: 0.4738 - val_cross_entropy: 3.7564 - val_fn: 35.0000 - val_fp: 185.0000 - val_loss: 1.7717 - val_precision: 0.3994 - val_recall: 0.7785 - val_tn: 75.0000 - val_tp: 123.0000
# Epoch 24/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - accuracy: 0.6305 - auc: 0.5578 - brier_score: 0.3563 - cross_entropy: 3.3345 - fn: 756.3333 - fp: 78.6667 - loss: 1.6065 - precision: 0.6276 - recall: 0.1490 - tn: 1292.6666 - tp: 132.3333 - val_accuracy: 0.5072 - val_auc: 0.5701 - val_brier_score: 0.4518 - val_cross_entropy: 3.4048 - val_fn: 36.0000 - val_fp: 170.0000 - val_loss: 1.7462 - val_precision: 0.4178 - val_recall: 0.7722 - val_tn: 90.0000 - val_tp: 122.0000
# Epoch 25/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 0.6290 - auc: 0.5611 - brier_score: 0.3571 - cross_entropy: 3.3441 - fn: 748.3333 - fp: 90.3333 - loss: 1.6009 - precision: 0.6073 - recall: 0.1571 - tn: 1282.0000 - tp: 139.3333 - val_accuracy: 0.5144 - val_auc: 0.5785 - val_brier_score: 0.4355 - val_cross_entropy: 3.0119 - val_fn: 46.0000 - val_fp: 157.0000 - val_loss: 1.7263 - val_precision: 0.4164 - val_recall: 0.7089 - val_tn: 103.0000 - val_tp: 112.0000
# Epoch 26/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.6333 - auc: 0.5645 - brier_score: 0.3508 - cross_entropy: 3.3301 - fn: 740.3333 - fp: 88.6667 - loss: 1.5925 - precision: 0.6192 - recall: 0.1631 - tn: 1287.0000 - tp: 144.0000 - val_accuracy: 0.5120 - val_auc: 0.5865 - val_brier_score: 0.4230 - val_cross_entropy: 2.7398 - val_fn: 56.0000 - val_fp: 148.0000 - val_loss: 1.7113 - val_precision: 0.4080 - val_recall: 0.6456 - val_tn: 112.0000 - val_tp: 102.0000
# Epoch 27/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.6282 - auc: 0.5689 - brier_score: 0.3569 - cross_entropy: 3.2557 - fn: 747.3333 - fp: 92.6667 - loss: 1.5928 - precision: 0.5975 - recall: 0.1557 - tn: 1282.0000 - tp: 138.0000 - val_accuracy: 0.5455 - val_auc: 0.5912 - val_brier_score: 0.4022 - val_cross_entropy: 2.5529 - val_fn: 60.0000 - val_fp: 130.0000 - val_loss: 1.6869 - val_precision: 0.4298 - val_recall: 0.6203 - val_tn: 130.0000 - val_tp: 98.0000
# Epoch 28/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 0.6316 - auc: 0.5696 - brier_score: 0.3533 - cross_entropy: 3.3287 - fn: 745.6667 - fp: 87.3333 - loss: 1.5831 - precision: 0.6127 - recall: 0.1559 - tn: 1289.3334 - tp: 137.6667 - val_accuracy: 0.5622 - val_auc: 0.5968 - val_brier_score: 0.3843 - val_cross_entropy: 2.4371 - val_fn: 66.0000 - val_fp: 117.0000 - val_loss: 1.6612 - val_precision: 0.4402 - val_recall: 0.5823 - val_tn: 143.0000 - val_tp: 92.0000
# Epoch 29/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 392ms/step - accuracy: 0.6278 - auc: 0.5708 - brier_score: 0.3559 - cross_entropy: 3.3959 - fn: 747.0000 - fp: 94.6667 - loss: 1.5805 - precision: 0.5893 - recall: 0.1540 - tn: 1282.6666 - tp: 135.6667 - val_accuracy: 0.5813 - val_auc: 0.6038 - val_brier_score: 0.3735 - val_cross_entropy: 2.3631 - val_fn: 68.0000 - val_fp: 107.0000 - val_loss: 1.6423 - val_precision: 0.4569 - val_recall: 0.5696 - val_tn: 153.0000 - val_tp: 90.0000
# Epoch 30/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 294ms/step - accuracy: 0.6363 - auc: 0.5567 - brier_score: 0.3519 - cross_entropy: 3.4527 - fn: 737.3333 - fp: 84.6667 - loss: 1.5706 - precision: 0.6371 - recall: 0.1679 - tn: 1289.3334 - tp: 148.6667 - val_accuracy: 0.5694 - val_auc: 0.6042 - val_brier_score: 0.3678 - val_cross_entropy: 2.3073 - val_fn: 76.0000 - val_fp: 104.0000 - val_loss: 1.6297 - val_precision: 0.4409 - val_recall: 0.5190 - val_tn: 156.0000 - val_tp: 82.0000
# Epoch 31/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.6291 - auc: 0.5698 - brier_score: 0.3515 - cross_entropy: 3.4277 - fn: 739.0000 - fp: 99.0000 - loss: 1.5655 - precision: 0.5972 - recall: 0.1658 - tn: 1275.0000 - tp: 147.0000 - val_accuracy: 0.5813 - val_auc: 0.6018 - val_brier_score: 0.3642 - val_cross_entropy: 2.2699 - val_fn: 76.0000 - val_fp: 99.0000 - val_loss: 1.6198 - val_precision: 0.4530 - val_recall: 0.5190 - val_tn: 161.0000 - val_tp: 82.0000
# Epoch 32/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 0.6251 - auc: 0.5713 - brier_score: 0.3573 - cross_entropy: 3.3758 - fn: 754.6667 - fp: 92.6667 - loss: 1.5656 - precision: 0.5850 - recall: 0.1476 - tn: 1282.0000 - tp: 130.6667 - val_accuracy: 0.5861 - val_auc: 0.5995 - val_brier_score: 0.3641 - val_cross_entropy: 2.3580 - val_fn: 71.0000 - val_fp: 102.0000 - val_loss: 1.6160 - val_precision: 0.4603 - val_recall: 0.5506 - val_tn: 158.0000 - val_tp: 87.0000
# Epoch 33/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.6307 - auc: 0.5825 - brier_score: 0.3528 - cross_entropy: 3.2970 - fn: 741.6667 - fp: 93.0000 - loss: 1.5572 - precision: 0.6067 - recall: 0.1620 - tn: 1282.0000 - tp: 143.3333 - val_accuracy: 0.5789 - val_auc: 0.6081 - val_brier_score: 0.3700 - val_cross_entropy: 2.5543 - val_fn: 64.0000 - val_fp: 112.0000 - val_loss: 1.6167 - val_precision: 0.4563 - val_recall: 0.5949 - val_tn: 148.0000 - val_tp: 94.0000
# Epoch 34/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 0.6329 - auc: 0.5671 - brier_score: 0.3514 - cross_entropy: 3.4592 - fn: 729.0000 - fp: 100.6667 - loss: 1.5503 - precision: 0.6093 - recall: 0.1772 - tn: 1273.3334 - tp: 157.0000 - val_accuracy: 0.5718 - val_auc: 0.6122 - val_brier_score: 0.3791 - val_cross_entropy: 2.7116 - val_fn: 62.0000 - val_fp: 117.0000 - val_loss: 1.6201 - val_precision: 0.4507 - val_recall: 0.6076 - val_tn: 143.0000 - val_tp: 96.0000
# Epoch 35/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - accuracy: 0.6303 - auc: 0.5624 - brier_score: 0.3558 - cross_entropy: 3.5188 - fn: 734.6667 - fp: 101.0000 - loss: 1.5491 - precision: 0.5984 - recall: 0.1698 - tn: 1274.0000 - tp: 150.3333 - val_accuracy: 0.5742 - val_auc: 0.6153 - val_brier_score: 0.3771 - val_cross_entropy: 2.7286 - val_fn: 64.0000 - val_fp: 114.0000 - val_loss: 1.6136 - val_precision: 0.4519 - val_recall: 0.5949 - val_tn: 146.0000 - val_tp: 94.0000
# Epoch 36/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 0.6330 - auc: 0.5820 - brier_score: 0.3489 - cross_entropy: 3.4564 - fn: 726.6667 - fp: 102.3333 - loss: 1.5380 - precision: 0.6111 - recall: 0.1813 - tn: 1270.0000 - tp: 161.0000 - val_accuracy: 0.5789 - val_auc: 0.6186 - val_brier_score: 0.3740 - val_cross_entropy: 2.7230 - val_fn: 65.0000 - val_fp: 111.0000 - val_loss: 1.6060 - val_precision: 0.4559 - val_recall: 0.5886 - val_tn: 149.0000 - val_tp: 93.0000
# Epoch 37/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.6402 - auc: 0.5711 - brier_score: 0.3464 - cross_entropy: 3.4714 - fn: 718.6667 - fp: 94.0000 - loss: 1.5279 - precision: 0.6451 - recall: 0.1917 - tn: 1276.6666 - tp: 170.6667 - val_accuracy: 0.5885 - val_auc: 0.6194 - val_brier_score: 0.3726 - val_cross_entropy: 2.6804 - val_fn: 65.0000 - val_fp: 107.0000 - val_loss: 1.5992 - val_precision: 0.4650 - val_recall: 0.5886 - val_tn: 153.0000 - val_tp: 93.0000
# Epoch 38/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.6392 - auc: 0.5806 - brier_score: 0.3477 - cross_entropy: 3.5462 - fn: 710.3333 - fp: 104.6667 - loss: 1.5250 - precision: 0.6310 - recall: 0.2011 - tn: 1266.0000 - tp: 179.0000 - val_accuracy: 0.5789 - val_auc: 0.6200 - val_brier_score: 0.3656 - val_cross_entropy: 2.5874 - val_fn: 71.0000 - val_fp: 105.0000 - val_loss: 1.5874 - val_precision: 0.4531 - val_recall: 0.5506 - val_tn: 155.0000 - val_tp: 87.0000
# Epoch 39/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 492ms/step - accuracy: 0.6317 - auc: 0.5857 - brier_score: 0.3505 - cross_entropy: 3.4479 - fn: 722.3333 - fp: 110.0000 - loss: 1.5245 - precision: 0.6002 - recall: 0.1861 - tn: 1262.6666 - tp: 165.0000 - val_accuracy: 0.5957 - val_auc: 0.6214 - val_brier_score: 0.3520 - val_cross_entropy: 2.4828 - val_fn: 74.0000 - val_fp: 95.0000 - val_loss: 1.5706 - val_precision: 0.4693 - val_recall: 0.5316 - val_tn: 165.0000 - val_tp: 84.0000
# Epoch 40/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 0.6316 - auc: 0.5621 - brier_score: 0.3550 - cross_entropy: 3.6840 - fn: 721.6667 - fp: 110.6667 - loss: 1.5238 - precision: 0.6005 - recall: 0.1874 - tn: 1261.3334 - tp: 166.3333 - val_accuracy: 0.6220 - val_auc: 0.6188 - val_brier_score: 0.3353 - val_cross_entropy: 2.3650 - val_fn: 77.0000 - val_fp: 81.0000 - val_loss: 1.5493 - val_precision: 0.5000 - val_recall: 0.5127 - val_tn: 179.0000 - val_tp: 81.0000
# Epoch 41/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.6375 - auc: 0.5783 - brier_score: 0.3489 - cross_entropy: 3.5463 - fn: 706.6667 - fp: 112.6667 - loss: 1.5168 - precision: 0.6139 - recall: 0.2020 - tn: 1261.6666 - tp: 179.0000 - val_accuracy: 0.6292 - val_auc: 0.6201 - val_brier_score: 0.3315 - val_cross_entropy: 2.3096 - val_fn: 79.0000 - val_fp: 76.0000 - val_loss: 1.5385 - val_precision: 0.5097 - val_recall: 0.5000 - val_tn: 184.0000 - val_tp: 79.0000
# Epoch 42/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 0.6343 - auc: 0.5794 - brier_score: 0.3485 - cross_entropy: 3.5951 - fn: 711.3333 - fp: 115.0000 - loss: 1.5096 - precision: 0.6063 - recall: 0.1992 - tn: 1256.6666 - tp: 177.0000 - val_accuracy: 0.6340 - val_auc: 0.6225 - val_brier_score: 0.3318 - val_cross_entropy: 2.2739 - val_fn: 79.0000 - val_fp: 74.0000 - val_loss: 1.5315 - val_precision: 0.5163 - val_recall: 0.5000 - val_tn: 186.0000 - val_tp: 79.0000
# Epoch 43/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 0.6325 - auc: 0.5804 - brier_score: 0.3509 - cross_entropy: 3.5905 - fn: 718.3333 - fp: 112.3333 - loss: 1.5091 - precision: 0.6003 - recall: 0.1897 - tn: 1261.0000 - tp: 168.3333 - val_accuracy: 0.6316 - val_auc: 0.6158 - val_brier_score: 0.3396 - val_cross_entropy: 2.2595 - val_fn: 78.0000 - val_fp: 76.0000 - val_loss: 1.5335 - val_precision: 0.5128 - val_recall: 0.5063 - val_tn: 184.0000 - val_tp: 80.0000
# Epoch 44/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.6279 - auc: 0.5695 - brier_score: 0.3552 - cross_entropy: 3.6394 - fn: 726.3333 - fp: 114.6667 - loss: 1.5085 - precision: 0.5792 - recall: 0.1786 - tn: 1261.0000 - tp: 158.0000 - val_accuracy: 0.6077 - val_auc: 0.6140 - val_brier_score: 0.3466 - val_cross_entropy: 2.2649 - val_fn: 80.0000 - val_fp: 84.0000 - val_loss: 1.5362 - val_precision: 0.4815 - val_recall: 0.4937 - val_tn: 176.0000 - val_tp: 78.0000
# Epoch 45/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.6402 - auc: 0.5883 - brier_score: 0.3444 - cross_entropy: 3.6940 - fn: 714.6667 - fp: 98.0000 - loss: 1.4931 - precision: 0.6350 - recall: 0.1929 - tn: 1276.3334 - tp: 171.0000 - val_accuracy: 0.5885 - val_auc: 0.6108 - val_brier_score: 0.3674 - val_cross_entropy: 2.3865 - val_fn: 75.0000 - val_fp: 97.0000 - val_loss: 1.5537 - val_precision: 0.4611 - val_recall: 0.5253 - val_tn: 163.0000 - val_tp: 83.0000
# Epoch 46/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - accuracy: 0.6328 - auc: 0.5760 - brier_score: 0.3503 - cross_entropy: 3.7975 - fn: 714.3333 - fp: 115.3333 - loss: 1.4920 - precision: 0.6062 - recall: 0.1986 - tn: 1253.3334 - tp: 177.0000 - val_accuracy: 0.5837 - val_auc: 0.6138 - val_brier_score: 0.3775 - val_cross_entropy: 2.5241 - val_fn: 70.0000 - val_fp: 104.0000 - val_loss: 1.5608 - val_precision: 0.4583 - val_recall: 0.5570 - val_tn: 156.0000 - val_tp: 88.0000
# Epoch 47/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.6276 - auc: 0.5709 - brier_score: 0.3567 - cross_entropy: 3.9123 - fn: 720.0000 - fp: 121.6667 - loss: 1.4981 - precision: 0.5744 - recall: 0.1856 - tn: 1254.0000 - tp: 164.3333 - val_accuracy: 0.5742 - val_auc: 0.6106 - val_brier_score: 0.3846 - val_cross_entropy: 2.6809 - val_fn: 65.0000 - val_fp: 113.0000 - val_loss: 1.5651 - val_precision: 0.4515 - val_recall: 0.5886 - val_tn: 147.0000 - val_tp: 93.0000
# Epoch 48/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.6393 - auc: 0.5817 - brier_score: 0.3473 - cross_entropy: 3.8392 - fn: 706.0000 - fp: 109.3333 - loss: 1.4837 - precision: 0.6260 - recall: 0.2054 - tn: 1262.3334 - tp: 182.3333 - val_accuracy: 0.5646 - val_auc: 0.6092 - val_brier_score: 0.3902 - val_cross_entropy: 2.8327 - val_fn: 64.0000 - val_fp: 118.0000 - val_loss: 1.5655 - val_precision: 0.4434 - val_recall: 0.5949 - val_tn: 142.0000 - val_tp: 94.0000
# Epoch 49/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 453ms/step - accuracy: 0.6246 - auc: 0.5675 - brier_score: 0.3605 - cross_entropy: 4.0395 - fn: 727.3333 - fp: 121.3333 - loss: 1.4905 - precision: 0.5761 - recall: 0.1842 - tn: 1247.3334 - tp: 164.0000 - val_accuracy: 0.5718 - val_auc: 0.6065 - val_brier_score: 0.3846 - val_cross_entropy: 2.8655 - val_fn: 64.0000 - val_fp: 115.0000 - val_loss: 1.5571 - val_precision: 0.4498 - val_recall: 0.5949 - val_tn: 145.0000 - val_tp: 94.0000
# Epoch 50/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 462ms/step - accuracy: 0.6373 - auc: 0.5818 - brier_score: 0.3495 - cross_entropy: 3.9465 - fn: 714.6667 - fp: 104.6667 - loss: 1.4783 - precision: 0.6178 - recall: 0.1917 - tn: 1271.0000 - tp: 169.6667 - val_accuracy: 0.5742 - val_auc: 0.6053 - val_brier_score: 0.3820 - val_cross_entropy: 2.9039 - val_fn: 66.0000 - val_fp: 112.0000 - val_loss: 1.5510 - val_precision: 0.4510 - val_recall: 0.5823 - val_tn: 148.0000 - val_tp: 92.0000
# Epoch 51/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - accuracy: 0.6351 - auc: 0.5713 - brier_score: 0.3499 - cross_entropy: 4.0228 - fn: 729.6667 - fp: 94.6667 - loss: 1.4723 - precision: 0.6290 - recall: 0.1802 - tn: 1275.3334 - tp: 160.3333 - val_accuracy: 0.5909 - val_auc: 0.6090 - val_brier_score: 0.3794 - val_cross_entropy: 2.8752 - val_fn: 70.0000 - val_fp: 101.0000 - val_loss: 1.5415 - val_precision: 0.4656 - val_recall: 0.5570 - val_tn: 159.0000 - val_tp: 88.0000
# Epoch 52/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 0.6444 - auc: 0.5793 - brier_score: 0.3440 - cross_entropy: 3.9509 - fn: 709.3333 - fp: 94.3333 - loss: 1.4649 - precision: 0.6520 - recall: 0.1994 - tn: 1279.6666 - tp: 176.6667 - val_accuracy: 0.5789 - val_auc: 0.6073 - val_brier_score: 0.3785 - val_cross_entropy: 2.8468 - val_fn: 73.0000 - val_fp: 103.0000 - val_loss: 1.5347 - val_precision: 0.4521 - val_recall: 0.5380 - val_tn: 157.0000 - val_tp: 85.0000
# Epoch 53/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - accuracy: 0.6426 - auc: 0.5885 - brier_score: 0.3439 - cross_entropy: 3.9421 - fn: 712.3333 - fp: 95.3333 - loss: 1.4602 - precision: 0.6472 - recall: 0.1971 - tn: 1277.6666 - tp: 174.6667 - val_accuracy: 0.5789 - val_auc: 0.6061 - val_brier_score: 0.3777 - val_cross_entropy: 2.8436 - val_fn: 74.0000 - val_fp: 102.0000 - val_loss: 1.5292 - val_precision: 0.4516 - val_recall: 0.5316 - val_tn: 158.0000 - val_tp: 84.0000
# Epoch 54/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - accuracy: 0.6366 - auc: 0.5763 - brier_score: 0.3482 - cross_entropy: 4.0552 - fn: 733.6667 - fp: 88.0000 - loss: 1.4647 - precision: 0.6295 - recall: 0.1692 - tn: 1289.0000 - tp: 149.3333 - val_accuracy: 0.5789 - val_auc: 0.6059 - val_brier_score: 0.3777 - val_cross_entropy: 2.8854 - val_fn: 75.0000 - val_fp: 101.0000 - val_loss: 1.5244 - val_precision: 0.4511 - val_recall: 0.5253 - val_tn: 159.0000 - val_tp: 83.0000
# Epoch 55/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.6378 - auc: 0.5893 - brier_score: 0.3475 - cross_entropy: 4.0969 - fn: 715.0000 - fp: 103.6667 - loss: 1.4553 - precision: 0.6265 - recall: 0.1951 - tn: 1268.0000 - tp: 173.3333 - val_accuracy: 0.5861 - val_auc: 0.6058 - val_brier_score: 0.3779 - val_cross_entropy: 2.9467 - val_fn: 76.0000 - val_fp: 97.0000 - val_loss: 1.5200 - val_precision: 0.4581 - val_recall: 0.5190 - val_tn: 163.0000 - val_tp: 82.0000
# Epoch 56/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 0.6376 - auc: 0.5783 - brier_score: 0.3509 - cross_entropy: 4.1492 - fn: 722.6667 - fp: 96.0000 - loss: 1.4546 - precision: 0.6313 - recall: 0.1854 - tn: 1276.6666 - tp: 164.6667 - val_accuracy: 0.5909 - val_auc: 0.6032 - val_brier_score: 0.3726 - val_cross_entropy: 2.9451 - val_fn: 79.0000 - val_fp: 92.0000 - val_loss: 1.5116 - val_precision: 0.4620 - val_recall: 0.5000 - val_tn: 168.0000 - val_tp: 79.0000
# Epoch 57/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - accuracy: 0.6389 - auc: 0.5855 - brier_score: 0.3495 - cross_entropy: 4.1074 - fn: 709.0000 - fp: 106.6667 - loss: 1.4498 - precision: 0.6259 - recall: 0.2011 - tn: 1265.6666 - tp: 178.6667 - val_accuracy: 0.6005 - val_auc: 0.6010 - val_brier_score: 0.3665 - val_cross_entropy: 2.9605 - val_fn: 77.0000 - val_fp: 90.0000 - val_loss: 1.5005 - val_precision: 0.4737 - val_recall: 0.5127 - val_tn: 170.0000 - val_tp: 81.0000
# Epoch 58/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 498ms/step - accuracy: 0.6444 - auc: 0.5868 - brier_score: 0.3417 - cross_entropy: 4.0955 - fn: 699.0000 - fp: 104.3333 - loss: 1.4387 - precision: 0.6456 - recall: 0.2137 - tn: 1266.6666 - tp: 190.0000 - val_accuracy: 0.6124 - val_auc: 0.6035 - val_brier_score: 0.3597 - val_cross_entropy: 3.0142 - val_fn: 76.0000 - val_fp: 86.0000 - val_loss: 1.4877 - val_precision: 0.4881 - val_recall: 0.5190 - val_tn: 174.0000 - val_tp: 82.0000
# Epoch 59/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 0.6372 - auc: 0.5812 - brier_score: 0.3480 - cross_entropy: 4.2504 - fn: 702.6667 - fp: 117.3333 - loss: 1.4448 - precision: 0.6058 - recall: 0.2040 - tn: 1259.6666 - tp: 180.3333 - val_accuracy: 0.6196 - val_auc: 0.6063 - val_brier_score: 0.3566 - val_cross_entropy: 3.0520 - val_fn: 77.0000 - val_fp: 82.0000 - val_loss: 1.4778 - val_precision: 0.4969 - val_recall: 0.5127 - val_tn: 178.0000 - val_tp: 81.0000
# Epoch 60/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - accuracy: 0.6438 - auc: 0.5867 - brier_score: 0.3442 - cross_entropy: 4.2356 - fn: 691.3333 - fp: 113.3333 - loss: 1.4360 - precision: 0.6329 - recall: 0.2204 - tn: 1259.6666 - tp: 195.6667 - val_accuracy: 0.6220 - val_auc: 0.6157 - val_brier_score: 0.3531 - val_cross_entropy: 3.0710 - val_fn: 78.0000 - val_fp: 80.0000 - val_loss: 1.4695 - val_precision: 0.5000 - val_recall: 0.5063 - val_tn: 180.0000 - val_tp: 80.0000
# Epoch 61/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 300ms/step - accuracy: 0.6498 - auc: 0.5912 - brier_score: 0.3377 - cross_entropy: 4.1913 - fn: 685.0000 - fp: 106.6667 - loss: 1.4288 - precision: 0.6523 - recall: 0.2263 - tn: 1268.3334 - tp: 200.0000 - val_accuracy: 0.6244 - val_auc: 0.6191 - val_brier_score: 0.3512 - val_cross_entropy: 3.0662 - val_fn: 80.0000 - val_fp: 77.0000 - val_loss: 1.4640 - val_precision: 0.5032 - val_recall: 0.4937 - val_tn: 183.0000 - val_tp: 78.0000
# Epoch 62/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 0.6345 - auc: 0.5821 - brier_score: 0.3515 - cross_entropy: 4.3893 - fn: 701.0000 - fp: 124.6667 - loss: 1.4356 - precision: 0.6017 - recall: 0.2118 - tn: 1246.0000 - tp: 188.3333 - val_accuracy: 0.6196 - val_auc: 0.6187 - val_brier_score: 0.3528 - val_cross_entropy: 3.0784 - val_fn: 81.0000 - val_fp: 78.0000 - val_loss: 1.4625 - val_precision: 0.4968 - val_recall: 0.4873 - val_tn: 182.0000 - val_tp: 77.0000
# Epoch 63/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 0.6421 - auc: 0.5791 - brier_score: 0.3463 - cross_entropy: 4.2848 - fn: 694.3333 - fp: 115.0000 - loss: 1.4297 - precision: 0.6218 - recall: 0.2139 - tn: 1262.0000 - tp: 188.6667 - val_accuracy: 0.6244 - val_auc: 0.6134 - val_brier_score: 0.3538 - val_cross_entropy: 3.0801 - val_fn: 83.0000 - val_fp: 74.0000 - val_loss: 1.4595 - val_precision: 0.5034 - val_recall: 0.4747 - val_tn: 186.0000 - val_tp: 75.0000
# Epoch 64/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 757ms/step - accuracy: 0.6446 - auc: 0.5825 - brier_score: 0.3430 - cross_entropy: 4.3689 - fn: 693.6667 - fp: 109.6667 - loss: 1.4247 - precision: 0.6335 - recall: 0.2146 - tn: 1267.0000 - tp: 189.6667 - val_accuracy: 0.6244 - val_auc: 0.6085 - val_brier_score: 0.3548 - val_cross_entropy: 3.0942 - val_fn: 84.0000 - val_fp: 73.0000 - val_loss: 1.4561 - val_precision: 0.5034 - val_recall: 0.4684 - val_tn: 187.0000 - val_tp: 74.0000
# Epoch 65/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 500ms/step - accuracy: 0.6370 - auc: 0.5756 - brier_score: 0.3498 - cross_entropy: 4.3627 - fn: 697.6667 - fp: 122.3333 - loss: 1.4275 - precision: 0.6061 - recall: 0.2127 - tn: 1251.3334 - tp: 188.6667 - val_accuracy: 0.6268 - val_auc: 0.6043 - val_brier_score: 0.3536 - val_cross_entropy: 3.0856 - val_fn: 84.0000 - val_fp: 72.0000 - val_loss: 1.4510 - val_precision: 0.5068 - val_recall: 0.4684 - val_tn: 188.0000 - val_tp: 74.0000
# Epoch 66/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 0.6356 - auc: 0.5671 - brier_score: 0.3524 - cross_entropy: 4.5505 - fn: 710.3333 - fp: 112.6667 - loss: 1.4228 - precision: 0.6131 - recall: 0.2008 - tn: 1258.3334 - tp: 178.6667 - val_accuracy: 0.6244 - val_auc: 0.5975 - val_brier_score: 0.3527 - val_cross_entropy: 3.0894 - val_fn: 85.0000 - val_fp: 72.0000 - val_loss: 1.4485 - val_precision: 0.5034 - val_recall: 0.4620 - val_tn: 188.0000 - val_tp: 73.0000
# Epoch 67/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 0.6429 - auc: 0.5886 - brier_score: 0.3469 - cross_entropy: 4.5367 - fn: 702.3333 - fp: 104.6667 - loss: 1.4153 - precision: 0.6387 - recall: 0.2086 - tn: 1268.0000 - tp: 185.0000 - val_accuracy: 0.6196 - val_auc: 0.6009 - val_brier_score: 0.3566 - val_cross_entropy: 3.1300 - val_fn: 84.0000 - val_fp: 75.0000 - val_loss: 1.4513 - val_precision: 0.4966 - val_recall: 0.4684 - val_tn: 185.0000 - val_tp: 74.0000
# Epoch 68/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - accuracy: 0.6469 - auc: 0.5825 - brier_score: 0.3424 - cross_entropy: 4.4587 - fn: 696.3333 - fp: 101.6667 - loss: 1.4088 - precision: 0.6518 - recall: 0.2143 - tn: 1272.0000 - tp: 190.0000 - val_accuracy: 0.6124 - val_auc: 0.5992 - val_brier_score: 0.3606 - val_cross_entropy: 3.2007 - val_fn: 83.0000 - val_fp: 79.0000 - val_loss: 1.4540 - val_precision: 0.4870 - val_recall: 0.4747 - val_tn: 181.0000 - val_tp: 75.0000
# Epoch 69/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - accuracy: 0.6394 - auc: 0.5730 - brier_score: 0.3503 - cross_entropy: 4.6420 - fn: 701.6667 - fp: 113.6667 - loss: 1.4150 - precision: 0.6160 - recall: 0.2060 - tn: 1262.6666 - tp: 182.0000 - val_accuracy: 0.6124 - val_auc: 0.6027 - val_brier_score: 0.3616 - val_cross_entropy: 3.2414 - val_fn: 81.0000 - val_fp: 81.0000 - val_loss: 1.4530 - val_precision: 0.4873 - val_recall: 0.4873 - val_tn: 179.0000 - val_tp: 77.0000
# Epoch 70/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 0.6400 - auc: 0.5907 - brier_score: 0.3491 - cross_entropy: 4.6272 - fn: 687.6667 - fp: 125.3333 - loss: 1.4073 - precision: 0.6202 - recall: 0.2292 - tn: 1242.3334 - tp: 204.6667 - val_accuracy: 0.6196 - val_auc: 0.6053 - val_brier_score: 0.3551 - val_cross_entropy: 3.2539 - val_fn: 81.0000 - val_fp: 78.0000 - val_loss: 1.4423 - val_precision: 0.4968 - val_recall: 0.4873 - val_tn: 182.0000 - val_tp: 77.0000
# Epoch 71/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - accuracy: 0.6366 - auc: 0.5829 - brier_score: 0.3475 - cross_entropy: 4.7092 - fn: 689.0000 - fp: 132.0000 - loss: 1.4055 - precision: 0.6025 - recall: 0.2248 - tn: 1239.0000 - tp: 200.0000 - val_accuracy: 0.6292 - val_auc: 0.6049 - val_brier_score: 0.3471 - val_cross_entropy: 3.2458 - val_fn: 81.0000 - val_fp: 74.0000 - val_loss: 1.4321 - val_precision: 0.5099 - val_recall: 0.4873 - val_tn: 186.0000 - val_tp: 77.0000
# Epoch 72/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 300ms/step - accuracy: 0.6268 - auc: 0.5713 - brier_score: 0.3584 - cross_entropy: 4.7410 - fn: 713.6667 - fp: 129.6667 - loss: 1.4144 - precision: 0.5704 - recall: 0.1943 - tn: 1244.3334 - tp: 172.3333 - val_accuracy: 0.6340 - val_auc: 0.5984 - val_brier_score: 0.3419 - val_cross_entropy: 3.2512 - val_fn: 87.0000 - val_fp: 66.0000 - val_loss: 1.4243 - val_precision: 0.5182 - val_recall: 0.4494 - val_tn: 194.0000 - val_tp: 71.0000
# Epoch 73/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step - accuracy: 0.6450 - auc: 0.5878 - brier_score: 0.3448 - cross_entropy: 4.6421 - fn: 686.3333 - fp: 115.6667 - loss: 1.3959 - precision: 0.6353 - recall: 0.2271 - tn: 1256.3334 - tp: 201.6667 - val_accuracy: 0.6411 - val_auc: 0.6068 - val_brier_score: 0.3395 - val_cross_entropy: 3.2669 - val_fn: 90.0000 - val_fp: 60.0000 - val_loss: 1.4167 - val_precision: 0.5312 - val_recall: 0.4304 - val_tn: 200.0000 - val_tp: 68.0000
# Epoch 74/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 497ms/step - accuracy: 0.6462 - auc: 0.5858 - brier_score: 0.3431 - cross_entropy: 4.7380 - fn: 689.3333 - fp: 110.3333 - loss: 1.3921 - precision: 0.6410 - recall: 0.2224 - tn: 1263.3334 - tp: 197.0000 - val_accuracy: 0.6411 - val_auc: 0.6066 - val_brier_score: 0.3378 - val_cross_entropy: 3.2936 - val_fn: 92.0000 - val_fp: 58.0000 - val_loss: 1.4137 - val_precision: 0.5323 - val_recall: 0.4177 - val_tn: 202.0000 - val_tp: 66.0000
# Epoch 75/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 335ms/step - accuracy: 0.6476 - auc: 0.5924 - brier_score: 0.3430 - cross_entropy: 4.7109 - fn: 684.0000 - fp: 112.0000 - loss: 1.3878 - precision: 0.6461 - recall: 0.2303 - tn: 1259.3334 - tp: 204.6667 - val_accuracy: 0.6483 - val_auc: 0.6085 - val_brier_score: 0.3369 - val_cross_entropy: 3.3455 - val_fn: 94.0000 - val_fp: 53.0000 - val_loss: 1.4082 - val_precision: 0.5470 - val_recall: 0.4051 - val_tn: 207.0000 - val_tp: 64.0000
# Epoch 76/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - accuracy: 0.6454 - auc: 0.5910 - brier_score: 0.3417 - cross_entropy: 4.7558 - fn: 690.0000 - fp: 112.0000 - loss: 1.3865 - precision: 0.6360 - recall: 0.2206 - tn: 1263.0000 - tp: 195.0000 - val_accuracy: 0.6435 - val_auc: 0.6045 - val_brier_score: 0.3368 - val_cross_entropy: 3.3356 - val_fn: 95.0000 - val_fp: 54.0000 - val_loss: 1.4047 - val_precision: 0.5385 - val_recall: 0.3987 - val_tn: 206.0000 - val_tp: 63.0000
# Epoch 77/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - accuracy: 0.6338 - auc: 0.5705 - brier_score: 0.3545 - cross_entropy: 4.9378 - fn: 721.0000 - fp: 106.6667 - loss: 1.3937 - precision: 0.6101 - recall: 0.1878 - tn: 1265.6666 - tp: 166.6667 - val_accuracy: 0.6364 - val_auc: 0.6060 - val_brier_score: 0.3358 - val_cross_entropy: 3.3317 - val_fn: 95.0000 - val_fp: 57.0000 - val_loss: 1.4020 - val_precision: 0.5250 - val_recall: 0.3987 - val_tn: 203.0000 - val_tp: 63.0000
# Epoch 78/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.6489 - auc: 0.5852 - brier_score: 0.3429 - cross_entropy: 4.6487 - fn: 702.0000 - fp: 91.3333 - loss: 1.3812 - precision: 0.6667 - recall: 0.2066 - tn: 1283.6666 - tp: 183.0000 - val_accuracy: 0.6411 - val_auc: 0.6082 - val_brier_score: 0.3372 - val_cross_entropy: 3.3485 - val_fn: 90.0000 - val_fp: 60.0000 - val_loss: 1.4017 - val_precision: 0.5312 - val_recall: 0.4304 - val_tn: 200.0000 - val_tp: 68.0000
# Epoch 79/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 428ms/step - accuracy: 0.6442 - auc: 0.5871 - brier_score: 0.3458 - cross_entropy: 4.7476 - fn: 701.6667 - fp: 102.6667 - loss: 1.3816 - precision: 0.6410 - recall: 0.2069 - tn: 1272.6666 - tp: 183.0000 - val_accuracy: 0.6364 - val_auc: 0.6032 - val_brier_score: 0.3419 - val_cross_entropy: 3.3753 - val_fn: 88.0000 - val_fp: 64.0000 - val_loss: 1.4033 - val_precision: 0.5224 - val_recall: 0.4430 - val_tn: 196.0000 - val_tp: 70.0000
# Epoch 80/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - accuracy: 0.6393 - auc: 0.5804 - brier_score: 0.3479 - cross_entropy: 4.7923 - fn: 700.6667 - fp: 114.6667 - loss: 1.3817 - precision: 0.6145 - recall: 0.2068 - tn: 1262.0000 - tp: 182.6667 - val_accuracy: 0.6364 - val_auc: 0.5995 - val_brier_score: 0.3431 - val_cross_entropy: 3.3987 - val_fn: 87.0000 - val_fp: 65.0000 - val_loss: 1.4005 - val_precision: 0.5221 - val_recall: 0.4494 - val_tn: 195.0000 - val_tp: 71.0000
# Epoch 81/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - accuracy: 0.6410 - auc: 0.5872 - brier_score: 0.3483 - cross_entropy: 4.8156 - fn: 701.0000 - fp: 110.6667 - loss: 1.3780 - precision: 0.6241 - recall: 0.2073 - tn: 1265.0000 - tp: 183.3333 - val_accuracy: 0.6483 - val_auc: 0.5970 - val_brier_score: 0.3394 - val_cross_entropy: 3.3872 - val_fn: 88.0000 - val_fp: 59.0000 - val_loss: 1.3938 - val_precision: 0.5426 - val_recall: 0.4430 - val_tn: 201.0000 - val_tp: 70.0000
# Epoch 82/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 522ms/step - accuracy: 0.6521 - auc: 0.5901 - brier_score: 0.3379 - cross_entropy: 4.7329 - fn: 692.0000 - fp: 94.3333 - loss: 1.3647 - precision: 0.6720 - recall: 0.2184 - tn: 1280.3334 - tp: 193.3333 - val_accuracy: 0.6507 - val_auc: 0.6026 - val_brier_score: 0.3359 - val_cross_entropy: 3.3509 - val_fn: 90.0000 - val_fp: 56.0000 - val_loss: 1.3869 - val_precision: 0.5484 - val_recall: 0.4304 - val_tn: 204.0000 - val_tp: 68.0000
# Epoch 83/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 484ms/step - accuracy: 0.6455 - auc: 0.5877 - brier_score: 0.3418 - cross_entropy: 4.8017 - fn: 695.3333 - fp: 106.0000 - loss: 1.3669 - precision: 0.6432 - recall: 0.2151 - tn: 1268.0000 - tp: 190.6667 - val_accuracy: 0.6531 - val_auc: 0.6069 - val_brier_score: 0.3347 - val_cross_entropy: 3.3464 - val_fn: 92.0000 - val_fp: 53.0000 - val_loss: 1.3814 - val_precision: 0.5546 - val_recall: 0.4177 - val_tn: 207.0000 - val_tp: 66.0000
# Epoch 84/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 384ms/step - accuracy: 0.6327 - auc: 0.5797 - brier_score: 0.3543 - cross_entropy: 4.9121 - fn: 709.0000 - fp: 121.3333 - loss: 1.3792 - precision: 0.5898 - recall: 0.1974 - tn: 1255.3334 - tp: 174.3333 - val_accuracy: 0.6483 - val_auc: 0.6147 - val_brier_score: 0.3319 - val_cross_entropy: 3.3425 - val_fn: 94.0000 - val_fp: 53.0000 - val_loss: 1.3777 - val_precision: 0.5470 - val_recall: 0.4051 - val_tn: 207.0000 - val_tp: 64.0000
# Epoch 85/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.6397 - auc: 0.5849 - brier_score: 0.3468 - cross_entropy: 4.9769 - fn: 696.0000 - fp: 118.0000 - loss: 1.3665 - precision: 0.6198 - recall: 0.2166 - tn: 1253.6666 - tp: 192.3333 - val_accuracy: 0.6507 - val_auc: 0.6159 - val_brier_score: 0.3293 - val_cross_entropy: 3.3591 - val_fn: 96.0000 - val_fp: 50.0000 - val_loss: 1.3730 - val_precision: 0.5536 - val_recall: 0.3924 - val_tn: 210.0000 - val_tp: 62.0000
# Epoch 86/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 368ms/step - accuracy: 0.6368 - auc: 0.5825 - brier_score: 0.3501 - cross_entropy: 4.8900 - fn: 694.6667 - fp: 126.0000 - loss: 1.3691 - precision: 0.6029 - recall: 0.2159 - tn: 1248.0000 - tp: 191.3333 - val_accuracy: 0.6507 - val_auc: 0.6169 - val_brier_score: 0.3288 - val_cross_entropy: 3.4306 - val_fn: 96.0000 - val_fp: 50.0000 - val_loss: 1.3697 - val_precision: 0.5536 - val_recall: 0.3924 - val_tn: 210.0000 - val_tp: 62.0000
# Epoch 87/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 0.6535 - auc: 0.5929 - brier_score: 0.3385 - cross_entropy: 4.8234 - fn: 667.0000 - fp: 116.0000 - loss: 1.3535 - precision: 0.6564 - recall: 0.2490 - tn: 1255.6666 - tp: 221.3333 - val_accuracy: 0.6507 - val_auc: 0.6153 - val_brier_score: 0.3291 - val_cross_entropy: 3.5016 - val_fn: 95.0000 - val_fp: 51.0000 - val_loss: 1.3677 - val_precision: 0.5526 - val_recall: 0.3987 - val_tn: 209.0000 - val_tp: 63.0000
# Epoch 88/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 316ms/step - accuracy: 0.6432 - auc: 0.5869 - brier_score: 0.3445 - cross_entropy: 4.9095 - fn: 678.3333 - fp: 128.0000 - loss: 1.3581 - precision: 0.6165 - recall: 0.2327 - tn: 1247.6666 - tp: 206.0000 - val_accuracy: 0.6603 - val_auc: 0.6176 - val_brier_score: 0.3280 - val_cross_entropy: 3.5533 - val_fn: 94.0000 - val_fp: 48.0000 - val_loss: 1.3641 - val_precision: 0.5714 - val_recall: 0.4051 - val_tn: 212.0000 - val_tp: 64.0000
# Epoch 89/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.6414 - auc: 0.5839 - brier_score: 0.3469 - cross_entropy: 4.8797 - fn: 678.0000 - fp: 132.3333 - loss: 1.3585 - precision: 0.6121 - recall: 0.2352 - tn: 1241.0000 - tp: 208.6667 - val_accuracy: 0.6555 - val_auc: 0.6155 - val_brier_score: 0.3275 - val_cross_entropy: 3.5678 - val_fn: 94.0000 - val_fp: 50.0000 - val_loss: 1.3605 - val_precision: 0.5614 - val_recall: 0.4051 - val_tn: 210.0000 - val_tp: 64.0000
# Epoch 90/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 454ms/step - accuracy: 0.6525 - auc: 0.5906 - brier_score: 0.3376 - cross_entropy: 4.8039 - fn: 654.0000 - fp: 131.6667 - loss: 1.3486 - precision: 0.6343 - recall: 0.2589 - tn: 1246.0000 - tp: 228.3333 - val_accuracy: 0.6531 - val_auc: 0.6108 - val_brier_score: 0.3274 - val_cross_entropy: 3.5631 - val_fn: 93.0000 - val_fp: 52.0000 - val_loss: 1.3580 - val_precision: 0.5556 - val_recall: 0.4114 - val_tn: 208.0000 - val_tp: 65.0000
# Epoch 91/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 508ms/step - accuracy: 0.6432 - auc: 0.5963 - brier_score: 0.3425 - cross_entropy: 4.9488 - fn: 651.3333 - fp: 155.3333 - loss: 1.3528 - precision: 0.5967 - recall: 0.2610 - tn: 1223.3334 - tp: 230.0000 - val_accuracy: 0.6483 - val_auc: 0.6113 - val_brier_score: 0.3271 - val_cross_entropy: 3.5621 - val_fn: 94.0000 - val_fp: 53.0000 - val_loss: 1.3556 - val_precision: 0.5470 - val_recall: 0.4051 - val_tn: 207.0000 - val_tp: 64.0000
# Epoch 92/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 460ms/step - accuracy: 0.6544 - auc: 0.6049 - brier_score: 0.3314 - cross_entropy: 4.6054 - fn: 636.6667 - fp: 145.0000 - loss: 1.3417 - precision: 0.6230 - recall: 0.2742 - tn: 1238.3334 - tp: 240.0000 - val_accuracy: 0.6459 - val_auc: 0.6128 - val_brier_score: 0.3282 - val_cross_entropy: 3.5773 - val_fn: 93.0000 - val_fp: 55.0000 - val_loss: 1.3543 - val_precision: 0.5417 - val_recall: 0.4114 - val_tn: 205.0000 - val_tp: 65.0000
# Epoch 93/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step - accuracy: 0.6374 - auc: 0.5934 - brier_score: 0.3489 - cross_entropy: 5.0064 - fn: 664.6667 - fp: 155.0000 - loss: 1.3518 - precision: 0.5894 - recall: 0.2504 - tn: 1218.3334 - tp: 222.0000 - val_accuracy: 0.6507 - val_auc: 0.6106 - val_brier_score: 0.3310 - val_cross_entropy: 3.5935 - val_fn: 91.0000 - val_fp: 55.0000 - val_loss: 1.3543 - val_precision: 0.5492 - val_recall: 0.4241 - val_tn: 205.0000 - val_tp: 67.0000
# Epoch 94/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.6438 - auc: 0.5856 - brier_score: 0.3458 - cross_entropy: 4.9826 - fn: 650.3333 - fp: 154.6667 - loss: 1.3454 - precision: 0.6072 - recall: 0.2685 - tn: 1216.3334 - tp: 238.6667 - val_accuracy: 0.6483 - val_auc: 0.6024 - val_brier_score: 0.3353 - val_cross_entropy: 3.6168 - val_fn: 92.0000 - val_fp: 55.0000 - val_loss: 1.3563 - val_precision: 0.5455 - val_recall: 0.4177 - val_tn: 205.0000 - val_tp: 66.0000
# Epoch 95/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.6396 - auc: 0.5938 - brier_score: 0.3480 - cross_entropy: 5.0239 - fn: 643.0000 - fp: 171.3333 - loss: 1.3463 - precision: 0.5889 - recall: 0.2761 - tn: 1200.3334 - tp: 245.3333 - val_accuracy: 0.6459 - val_auc: 0.6082 - val_brier_score: 0.3394 - val_cross_entropy: 3.6283 - val_fn: 92.0000 - val_fp: 56.0000 - val_loss: 1.3574 - val_precision: 0.5410 - val_recall: 0.4177 - val_tn: 204.0000 - val_tp: 66.0000
# Epoch 96/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 429ms/step - accuracy: 0.6365 - auc: 0.5814 - brier_score: 0.3514 - cross_entropy: 5.1464 - fn: 642.6667 - fp: 179.0000 - loss: 1.3469 - precision: 0.5772 - recall: 0.2753 - tn: 1194.3334 - tp: 244.0000 - val_accuracy: 0.6435 - val_auc: 0.6113 - val_brier_score: 0.3373 - val_cross_entropy: 3.5988 - val_fn: 94.0000 - val_fp: 55.0000 - val_loss: 1.3526 - val_precision: 0.5378 - val_recall: 0.4051 - val_tn: 205.0000 - val_tp: 64.0000
# Epoch 97/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 0.6462 - auc: 0.5890 - brier_score: 0.3435 - cross_entropy: 5.0660 - fn: 645.0000 - fp: 154.6667 - loss: 1.3385 - precision: 0.6078 - recall: 0.2709 - tn: 1220.6666 - tp: 239.6667 - val_accuracy: 0.6507 - val_auc: 0.6087 - val_brier_score: 0.3329 - val_cross_entropy: 3.5530 - val_fn: 94.0000 - val_fp: 52.0000 - val_loss: 1.3472 - val_precision: 0.5517 - val_recall: 0.4051 - val_tn: 208.0000 - val_tp: 64.0000
# Epoch 98/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - accuracy: 0.6590 - auc: 0.6037 - brier_score: 0.3310 - cross_entropy: 4.7937 - fn: 637.0000 - fp: 133.6667 - loss: 1.3228 - precision: 0.6499 - recall: 0.2802 - tn: 1241.3334 - tp: 248.0000 - val_accuracy: 0.6459 - val_auc: 0.6101 - val_brier_score: 0.3296 - val_cross_entropy: 3.5575 - val_fn: 99.0000 - val_fp: 49.0000 - val_loss: 1.3420 - val_precision: 0.5463 - val_recall: 0.3734 - val_tn: 211.0000 - val_tp: 59.0000
# Epoch 99/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - accuracy: 0.6457 - auc: 0.5915 - brier_score: 0.3451 - cross_entropy: 4.9489 - fn: 652.0000 - fp: 149.0000 - loss: 1.3355 - precision: 0.6057 - recall: 0.2599 - tn: 1230.0000 - tp: 229.0000 - val_accuracy: 0.6555 - val_auc: 0.6079 - val_brier_score: 0.3289 - val_cross_entropy: 3.5670 - val_fn: 99.0000 - val_fp: 45.0000 - val_loss: 1.3361 - val_precision: 0.5673 - val_recall: 0.3734 - val_tn: 215.0000 - val_tp: 59.0000
# Epoch 100/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - accuracy: 0.6513 - auc: 0.5927 - brier_score: 0.3398 - cross_entropy: 4.8425 - fn: 662.0000 - fp: 126.0000 - loss: 1.3264 - precision: 0.6397 - recall: 0.2526 - tn: 1248.3334 - tp: 223.6667 - val_accuracy: 0.6579 - val_auc: 0.6074 - val_brier_score: 0.3279 - val_cross_entropy: 3.5718 - val_fn: 100.0000 - val_fp: 43.0000 - val_loss: 1.3318 - val_precision: 0.5743 - val_recall: 0.3671 - val_tn: 217.0000 - val_tp: 58.0000
# Epoch 101/400
# ...
# Epoch 368/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 335ms/step - accuracy: 0.6744 - auc: 0.6236 - brier_score: 0.3188 - cross_entropy: 5.9501 - fn: 598.6667 - fp: 136.6667 - loss: 1.0681 - precision: 0.6822 - recall: 0.3283 - tn: 1231.6666 - tp: 293.0000 - val_accuracy: 0.6770 - val_auc: 0.6058 - val_brier_score: 0.3201 - val_cross_entropy: 5.5896 - val_fn: 117.0000 - val_fp: 18.0000 - val_loss: 1.0838 - val_precision: 0.6949 - val_recall: 0.2595 - val_tn: 242.0000 - val_tp: 41.0000
# Epoch 369/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - accuracy: 0.6763 - auc: 0.6309 - brier_score: 0.3155 - cross_entropy: 5.9701 - fn: 577.6667 - fp: 154.0000 - loss: 1.0706 - precision: 0.6621 - recall: 0.3435 - tn: 1226.0000 - tp: 302.3333 - val_accuracy: 0.6722 - val_auc: 0.6051 - val_brier_score: 0.3212 - val_cross_entropy: 5.5653 - val_fn: 118.0000 - val_fp: 19.0000 - val_loss: 1.0848 - val_precision: 0.6780 - val_recall: 0.2532 - val_tn: 241.0000 - val_tp: 40.0000
# Epoch 370/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 0.6711 - auc: 0.6216 - brier_score: 0.3226 - cross_entropy: 5.9319 - fn: 591.3333 - fp: 152.3333 - loss: 1.0749 - precision: 0.6586 - recall: 0.3320 - tn: 1222.6666 - tp: 293.6667 - val_accuracy: 0.6722 - val_auc: 0.6026 - val_brier_score: 0.3235 - val_cross_entropy: 5.5038 - val_fn: 117.0000 - val_fp: 20.0000 - val_loss: 1.0861 - val_precision: 0.6721 - val_recall: 0.2595 - val_tn: 240.0000 - val_tp: 41.0000
# Epoch 371/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - accuracy: 0.6717 - auc: 0.6288 - brier_score: 0.3207 - cross_entropy: 6.0425 - fn: 587.0000 - fp: 155.0000 - loss: 1.0727 - precision: 0.6567 - recall: 0.3359 - tn: 1221.3334 - tp: 296.6667 - val_accuracy: 0.6722 - val_auc: 0.5985 - val_brier_score: 0.3243 - val_cross_entropy: 5.4717 - val_fn: 117.0000 - val_fp: 20.0000 - val_loss: 1.0860 - val_precision: 0.6721 - val_recall: 0.2595 - val_tn: 240.0000 - val_tp: 41.0000
# Epoch 372/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.6768 - auc: 0.6318 - brier_score: 0.3139 - cross_entropy: 5.6504 - fn: 589.6667 - fp: 140.6667 - loss: 1.0650 - precision: 0.6775 - recall: 0.3337 - tn: 1234.0000 - tp: 295.6667 - val_accuracy: 0.6722 - val_auc: 0.5998 - val_brier_score: 0.3232 - val_cross_entropy: 5.4710 - val_fn: 117.0000 - val_fp: 20.0000 - val_loss: 1.0846 - val_precision: 0.6721 - val_recall: 0.2595 - val_tn: 240.0000 - val_tp: 41.0000
# Epoch 373/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.6826 - auc: 0.6314 - brier_score: 0.3120 - cross_entropy: 5.9097 - fn: 577.3333 - fp: 140.0000 - loss: 1.0628 - precision: 0.6869 - recall: 0.3474 - tn: 1235.3334 - tp: 307.3333 - val_accuracy: 0.6746 - val_auc: 0.6043 - val_brier_score: 0.3218 - val_cross_entropy: 5.4754 - val_fn: 116.0000 - val_fp: 20.0000 - val_loss: 1.0827 - val_precision: 0.6774 - val_recall: 0.2658 - val_tn: 240.0000 - val_tp: 42.0000
# Epoch 374/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - accuracy: 0.6783 - auc: 0.6295 - brier_score: 0.3148 - cross_entropy: 5.9596 - fn: 583.3333 - fp: 143.6667 - loss: 1.0659 - precision: 0.6771 - recall: 0.3406 - tn: 1231.6666 - tp: 301.3333 - val_accuracy: 0.6770 - val_auc: 0.6044 - val_brier_score: 0.3196 - val_cross_entropy: 5.5038 - val_fn: 116.0000 - val_fp: 19.0000 - val_loss: 1.0799 - val_precision: 0.6885 - val_recall: 0.2658 - val_tn: 241.0000 - val_tp: 42.0000
# Epoch 375/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 488ms/step - accuracy: 0.6819 - auc: 0.6400 - brier_score: 0.3100 - cross_entropy: 5.6560 - fn: 571.6667 - fp: 147.0000 - loss: 1.0593 - precision: 0.6837 - recall: 0.3569 - tn: 1224.0000 - tp: 317.3333 - val_accuracy: 0.6794 - val_auc: 0.6014 - val_brier_score: 0.3180 - val_cross_entropy: 5.5277 - val_fn: 116.0000 - val_fp: 18.0000 - val_loss: 1.0779 - val_precision: 0.7000 - val_recall: 0.2658 - val_tn: 242.0000 - val_tp: 42.0000
# Epoch 376/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 522ms/step - accuracy: 0.6822 - auc: 0.6279 - brier_score: 0.3123 - cross_entropy: 5.8355 - fn: 575.6667 - fp: 142.6667 - loss: 1.0618 - precision: 0.6857 - recall: 0.3509 - tn: 1230.6666 - tp: 311.0000 - val_accuracy: 0.6770 - val_auc: 0.6056 - val_brier_score: 0.3190 - val_cross_entropy: 5.5328 - val_fn: 115.0000 - val_fp: 20.0000 - val_loss: 1.0793 - val_precision: 0.6825 - val_recall: 0.2722 - val_tn: 240.0000 - val_tp: 43.0000
# Epoch 377/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - accuracy: 0.6647 - auc: 0.6210 - brier_score: 0.3270 - cross_entropy: 6.1045 - fn: 597.6667 - fp: 160.0000 - loss: 1.0742 - precision: 0.6461 - recall: 0.3280 - tn: 1210.6666 - tp: 291.6667 - val_accuracy: 0.6746 - val_auc: 0.6047 - val_brier_score: 0.3217 - val_cross_entropy: 5.5137 - val_fn: 114.0000 - val_fp: 22.0000 - val_loss: 1.0806 - val_precision: 0.6667 - val_recall: 0.2785 - val_tn: 238.0000 - val_tp: 44.0000
# Epoch 378/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.6813 - auc: 0.6331 - brier_score: 0.3132 - cross_entropy: 5.8295 - fn: 575.0000 - fp: 145.6667 - loss: 1.0615 - precision: 0.6804 - recall: 0.3503 - tn: 1229.6666 - tp: 309.6667 - val_accuracy: 0.6770 - val_auc: 0.6060 - val_brier_score: 0.3204 - val_cross_entropy: 5.4720 - val_fn: 114.0000 - val_fp: 21.0000 - val_loss: 1.0796 - val_precision: 0.6769 - val_recall: 0.2785 - val_tn: 239.0000 - val_tp: 44.0000
# Epoch 379/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step - accuracy: 0.6804 - auc: 0.6351 - brier_score: 0.3123 - cross_entropy: 5.9570 - fn: 592.6667 - fp: 129.6667 - loss: 1.0606 - precision: 0.6944 - recall: 0.3318 - tn: 1243.3334 - tp: 294.3333 - val_accuracy: 0.6746 - val_auc: 0.6090 - val_brier_score: 0.3185 - val_cross_entropy: 5.4507 - val_fn: 115.0000 - val_fp: 21.0000 - val_loss: 1.0780 - val_precision: 0.6719 - val_recall: 0.2722 - val_tn: 239.0000 - val_tp: 43.0000
# Epoch 380/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - accuracy: 0.6738 - auc: 0.6325 - brier_score: 0.3168 - cross_entropy: 5.7963 - fn: 591.6667 - fp: 145.6667 - loss: 1.0677 - precision: 0.6649 - recall: 0.3283 - tn: 1233.3334 - tp: 289.3333 - val_accuracy: 0.6770 - val_auc: 0.6092 - val_brier_score: 0.3181 - val_cross_entropy: 5.4479 - val_fn: 116.0000 - val_fp: 19.0000 - val_loss: 1.0768 - val_precision: 0.6885 - val_recall: 0.2658 - val_tn: 241.0000 - val_tp: 42.0000
# Epoch 381/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.6683 - auc: 0.6170 - brier_score: 0.3251 - cross_entropy: 6.0781 - fn: 594.6667 - fp: 155.0000 - loss: 1.0727 - precision: 0.6519 - recall: 0.3281 - tn: 1220.0000 - tp: 290.3333 - val_accuracy: 0.6770 - val_auc: 0.6094 - val_brier_score: 0.3189 - val_cross_entropy: 5.4245 - val_fn: 116.0000 - val_fp: 19.0000 - val_loss: 1.0771 - val_precision: 0.6885 - val_recall: 0.2658 - val_tn: 241.0000 - val_tp: 42.0000
# Epoch 382/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step - accuracy: 0.6843 - auc: 0.6421 - brier_score: 0.3085 - cross_entropy: 5.6580 - fn: 568.0000 - fp: 145.3333 - loss: 1.0561 - precision: 0.6861 - recall: 0.3584 - tn: 1229.0000 - tp: 317.6667 - val_accuracy: 0.6770 - val_auc: 0.6111 - val_brier_score: 0.3191 - val_cross_entropy: 5.3417 - val_fn: 116.0000 - val_fp: 19.0000 - val_loss: 1.0780 - val_precision: 0.6885 - val_recall: 0.2658 - val_tn: 241.0000 - val_tp: 42.0000
# Epoch 383/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - accuracy: 0.6681 - auc: 0.6218 - brier_score: 0.3237 - cross_entropy: 6.0188 - fn: 584.0000 - fp: 165.6667 - loss: 1.0701 - precision: 0.6470 - recall: 0.3422 - tn: 1206.3334 - tp: 304.0000 - val_accuracy: 0.6746 - val_auc: 0.6173 - val_brier_score: 0.3184 - val_cross_entropy: 5.2330 - val_fn: 117.0000 - val_fp: 19.0000 - val_loss: 1.0794 - val_precision: 0.6833 - val_recall: 0.2595 - val_tn: 241.0000 - val_tp: 41.0000
# Epoch 384/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 410ms/step - accuracy: 0.6806 - auc: 0.6367 - brier_score: 0.3114 - cross_entropy: 5.6398 - fn: 585.6667 - fp: 136.0000 - loss: 1.0573 - precision: 0.6903 - recall: 0.3409 - tn: 1235.3334 - tp: 303.0000 - val_accuracy: 0.6675 - val_auc: 0.6142 - val_brier_score: 0.3209 - val_cross_entropy: 5.1448 - val_fn: 118.0000 - val_fp: 21.0000 - val_loss: 1.0826 - val_precision: 0.6557 - val_recall: 0.2532 - val_tn: 239.0000 - val_tp: 40.0000
# Epoch 385/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 548ms/step - accuracy: 0.6724 - auc: 0.6234 - brier_score: 0.3191 - cross_entropy: 5.8248 - fn: 599.3333 - fp: 141.3333 - loss: 1.0674 - precision: 0.6669 - recall: 0.3208 - tn: 1236.3334 - tp: 283.0000 - val_accuracy: 0.6651 - val_auc: 0.6173 - val_brier_score: 0.3235 - val_cross_entropy: 5.1032 - val_fn: 118.0000 - val_fp: 22.0000 - val_loss: 1.0840 - val_precision: 0.6452 - val_recall: 0.2532 - val_tn: 238.0000 - val_tp: 40.0000
# Epoch 386/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 515ms/step - accuracy: 0.6789 - auc: 0.6310 - brier_score: 0.3152 - cross_entropy: 5.9138 - fn: 592.0000 - fp: 134.0000 - loss: 1.0623 - precision: 0.6858 - recall: 0.3305 - tn: 1242.0000 - tp: 292.0000 - val_accuracy: 0.6675 - val_auc: 0.6177 - val_brier_score: 0.3260 - val_cross_entropy: 5.1160 - val_fn: 117.0000 - val_fp: 22.0000 - val_loss: 1.0846 - val_precision: 0.6508 - val_recall: 0.2595 - val_tn: 238.0000 - val_tp: 41.0000
# Epoch 387/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - accuracy: 0.6676 - auc: 0.6117 - brier_score: 0.3249 - cross_entropy: 6.1425 - fn: 613.0000 - fp: 138.0000 - loss: 1.0714 - precision: 0.6619 - recall: 0.3062 - tn: 1238.3334 - tp: 270.6667 - val_accuracy: 0.6699 - val_auc: 0.6095 - val_brier_score: 0.3258 - val_cross_entropy: 5.1496 - val_fn: 116.0000 - val_fp: 22.0000 - val_loss: 1.0825 - val_precision: 0.6562 - val_recall: 0.2658 - val_tn: 238.0000 - val_tp: 42.0000
# Epoch 388/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step - accuracy: 0.6777 - auc: 0.6236 - brier_score: 0.3150 - cross_entropy: 6.1533 - fn: 604.3333 - fp: 124.6667 - loss: 1.0609 - precision: 0.6916 - recall: 0.3162 - tn: 1252.0000 - tp: 279.0000 - val_accuracy: 0.6699 - val_auc: 0.5999 - val_brier_score: 0.3241 - val_cross_entropy: 5.2115 - val_fn: 116.0000 - val_fp: 22.0000 - val_loss: 1.0801 - val_precision: 0.6562 - val_recall: 0.2658 - val_tn: 238.0000 - val_tp: 42.0000
# Epoch 389/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 0.6768 - auc: 0.6251 - brier_score: 0.3183 - cross_entropy: 6.0050 - fn: 600.3333 - fp: 130.6667 - loss: 1.0653 - precision: 0.6823 - recall: 0.3190 - tn: 1248.3334 - tp: 280.6667 - val_accuracy: 0.6746 - val_auc: 0.5954 - val_brier_score: 0.3211 - val_cross_entropy: 5.2722 - val_fn: 116.0000 - val_fp: 20.0000 - val_loss: 1.0772 - val_precision: 0.6774 - val_recall: 0.2658 - val_tn: 240.0000 - val_tp: 42.0000
# Epoch 390/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - accuracy: 0.6702 - auc: 0.6233 - brier_score: 0.3228 - cross_entropy: 5.9523 - fn: 615.3333 - fp: 130.0000 - loss: 1.0666 - precision: 0.6755 - recall: 0.3056 - tn: 1244.0000 - tp: 270.6667 - val_accuracy: 0.6770 - val_auc: 0.5974 - val_brier_score: 0.3192 - val_cross_entropy: 5.3409 - val_fn: 116.0000 - val_fp: 19.0000 - val_loss: 1.0748 - val_precision: 0.6885 - val_recall: 0.2658 - val_tn: 241.0000 - val_tp: 42.0000
# Epoch 391/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.6704 - auc: 0.6206 - brier_score: 0.3230 - cross_entropy: 6.0405 - fn: 624.3333 - fp: 120.0000 - loss: 1.0675 - precision: 0.6840 - recall: 0.2942 - tn: 1255.0000 - tp: 260.6667 - val_accuracy: 0.6770 - val_auc: 0.5959 - val_brier_score: 0.3184 - val_cross_entropy: 5.3609 - val_fn: 117.0000 - val_fp: 18.0000 - val_loss: 1.0740 - val_precision: 0.6949 - val_recall: 0.2595 - val_tn: 242.0000 - val_tp: 41.0000
# Epoch 392/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.6900 - auc: 0.6374 - brier_score: 0.3048 - cross_entropy: 5.6588 - fn: 586.6667 - fp: 114.3333 - loss: 1.0501 - precision: 0.7225 - recall: 0.3364 - tn: 1261.6666 - tp: 297.3333 - val_accuracy: 0.6746 - val_auc: 0.5987 - val_brier_score: 0.3170 - val_cross_entropy: 5.3362 - val_fn: 117.0000 - val_fp: 19.0000 - val_loss: 1.0726 - val_precision: 0.6833 - val_recall: 0.2595 - val_tn: 241.0000 - val_tp: 41.0000
# Epoch 393/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.6757 - auc: 0.6249 - brier_score: 0.3190 - cross_entropy: 5.8590 - fn: 609.6667 - fp: 123.6667 - loss: 1.0628 - precision: 0.6904 - recall: 0.3113 - tn: 1251.3334 - tp: 275.3333 - val_accuracy: 0.6818 - val_auc: 0.5966 - val_brier_score: 0.3146 - val_cross_entropy: 5.2868 - val_fn: 116.0000 - val_fp: 17.0000 - val_loss: 1.0698 - val_precision: 0.7119 - val_recall: 0.2658 - val_tn: 243.0000 - val_tp: 42.0000
# Epoch 394/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 411ms/step - accuracy: 0.6728 - auc: 0.6342 - brier_score: 0.3188 - cross_entropy: 5.9288 - fn: 599.0000 - fp: 140.0000 - loss: 1.0613 - precision: 0.6747 - recall: 0.3262 - tn: 1230.6666 - tp: 290.3333 - val_accuracy: 0.6818 - val_auc: 0.6040 - val_brier_score: 0.3142 - val_cross_entropy: 5.2296 - val_fn: 116.0000 - val_fp: 17.0000 - val_loss: 1.0686 - val_precision: 0.7119 - val_recall: 0.2658 - val_tn: 243.0000 - val_tp: 42.0000
# Epoch 395/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 481ms/step - accuracy: 0.6810 - auc: 0.6362 - brier_score: 0.3103 - cross_entropy: 5.7083 - fn: 579.0000 - fp: 142.0000 - loss: 1.0551 - precision: 0.6821 - recall: 0.3447 - tn: 1234.3334 - tp: 304.6667 - val_accuracy: 0.6818 - val_auc: 0.6071 - val_brier_score: 0.3148 - val_cross_entropy: 5.1833 - val_fn: 116.0000 - val_fp: 17.0000 - val_loss: 1.0691 - val_precision: 0.7119 - val_recall: 0.2658 - val_tn: 243.0000 - val_tp: 42.0000
# Epoch 396/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 491ms/step - accuracy: 0.6755 - auc: 0.6266 - brier_score: 0.3204 - cross_entropy: 6.0482 - fn: 577.3333 - fp: 156.0000 - loss: 1.0639 - precision: 0.6631 - recall: 0.3474 - tn: 1219.3334 - tp: 307.3333 - val_accuracy: 0.6770 - val_auc: 0.6111 - val_brier_score: 0.3165 - val_cross_entropy: 5.1826 - val_fn: 115.0000 - val_fp: 20.0000 - val_loss: 1.0716 - val_precision: 0.6825 - val_recall: 0.2722 - val_tn: 240.0000 - val_tp: 43.0000
# Epoch 397/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 441ms/step - accuracy: 0.6759 - auc: 0.6295 - brier_score: 0.3167 - cross_entropy: 5.8148 - fn: 580.0000 - fp: 152.3333 - loss: 1.0590 - precision: 0.6701 - recall: 0.3475 - tn: 1218.6666 - tp: 309.0000 - val_accuracy: 0.6746 - val_auc: 0.6119 - val_brier_score: 0.3171 - val_cross_entropy: 5.2104 - val_fn: 114.0000 - val_fp: 22.0000 - val_loss: 1.0717 - val_precision: 0.6667 - val_recall: 0.2785 - val_tn: 238.0000 - val_tp: 44.0000
# Epoch 398/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 361ms/step - accuracy: 0.6739 - auc: 0.6302 - brier_score: 0.3184 - cross_entropy: 6.1338 - fn: 574.6667 - fp: 162.3333 - loss: 1.0626 - precision: 0.6562 - recall: 0.3504 - tn: 1213.0000 - tp: 310.0000 - val_accuracy: 0.6794 - val_auc: 0.6143 - val_brier_score: 0.3163 - val_cross_entropy: 5.2685 - val_fn: 112.0000 - val_fp: 22.0000 - val_loss: 1.0700 - val_precision: 0.6765 - val_recall: 0.2911 - val_tn: 238.0000 - val_tp: 46.0000
# Epoch 399/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.6757 - auc: 0.6326 - brier_score: 0.3148 - cross_entropy: 5.9694 - fn: 587.0000 - fp: 145.6667 - loss: 1.0576 - precision: 0.6713 - recall: 0.3365 - tn: 1229.3334 - tp: 298.0000 - val_accuracy: 0.6770 - val_auc: 0.6147 - val_brier_score: 0.3168 - val_cross_entropy: 5.3165 - val_fn: 113.0000 - val_fp: 22.0000 - val_loss: 1.0705 - val_precision: 0.6716 - val_recall: 0.2848 - val_tn: 238.0000 - val_tp: 45.0000
# Epoch 400/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step - accuracy: 0.6687 - auc: 0.6200 - brier_score: 0.3248 - cross_entropy: 6.2607 - fn: 585.0000 - fp: 163.6667 - loss: 1.0679 - precision: 0.6453 - recall: 0.3375 - tn: 1213.0000 - tp: 298.3333 - val_accuracy: 0.6746 - val_auc: 0.6126 - val_brier_score: 0.3207 - val_cross_entropy: 5.3859 - val_fn: 113.0000 - val_fp: 23.0000 - val_loss: 1.0750 - val_precision: 0.6618 - val_recall: 0.2848 - val_tn: 237.0000 - val_tp: 45.0000

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
test_loss, *other_metrics = model.evaluate(test_features, test_labels, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 1.0861

# %%
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.axhline(y=test_loss, color='g', linestyle='--', label='Test loss')
plt.title('Training, Validation, and Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ###Evaluate metrics
# I would use a confusion matrix to summarize the actual vs. predicted labels, where the X axis is the predicted label and the Y axis is the actual label:

# %%
test_predictions_baseline = model.predict(test_features, batch_size=BATCH_SIZE)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step

# %%
def plot_cm(labels, predictions, threshold=0.5):
  cm = confusion_matrix(labels, predictions > threshold)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(threshold))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Non-Potable Water Detected (True Negatives): ', cm[0][0])
  print('Non-Potable Water Incorrectly Detected (False Positives): ', cm[0][1])
  print('Potable Water Missed (False Negatives): ', cm[1][0])
  print('Potable Water Detected (True Positives): ', cm[1][1])
  print('Total Potable Water: ', np.sum(cm[1]))

# %%
plot_cm(test_labels, test_predictions_baseline)
# Out:
# Non-Potable Water Detected (True Negatives):  275
# Non-Potable Water Incorrectly Detected (False Positives):  24
# Potable Water Missed (False Negatives):  150
# Potable Water Detected (True Positives):  43
# Total Potable Water:  193

# %%
threshold = 0.5
test_predictions_binary = (test_predictions_baseline > threshold).astype(int)

# %%
f1 = f1_score(test_labels, test_predictions_binary)
precision = precision_score(test_labels, test_predictions_binary)
recall = recall_score(test_labels, test_predictions_binary)

print(f"F1 Score: {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
# Out:
# F1 Score: 0.3308
# Precision: 0.6418
# Recall: 0.2228
